# %% [markdown]
# ## This code is simply importing two Python libraries:
#
# **1. requests:**
#
# A popular library for sending HTTP requests in Python. It simplifies making requests to web pages or APIs, handling methods like GET, POST, PUT, DELETE, etc.
#
#
# **2. pandas (imported as pd):**
#
# A widely-used library for data manipulation and analysis. It provides data structures and tools for working with structured data (like CSVs, Excel files, SQL databases, etc.).
#
# **By importing these libraries, the script is set up to:**
#
#
# Use requests to fetch data or interact with web services.
#
# Use pandas (referred to as pd in the code) to load, transform, analyze, and manipulate the data once it is obtained.

# %%
import requests
import pandas as pd

# %% [markdown]
# We are going to use API.
#
# An API (Application Programming Interface) is a set of rules and protocols that allows different software applications to communicate with each other. In practical terms, it defines how a programmer can request data or services from another application or service, and how that other application or service should respond to those requests.
#
# For instance, a web API might allow developers to send a request—often using the HTTP protocol—to obtain information (such as stock prices, weather forecasts, or user data). The API then returns the requested data in a structured format (usually JSON or XML) that the developer’s application can process and use. This abstraction makes it easier to integrate services without needing to know the internal details of how the other application is implemented.
#
# The API are provided by a cloud service:
#
# https://api.exchangerate.host
#
#
# a freely available web API that provides current and historical foreign exchange rates. It allows developers and applications to:
#
# - Retrieve real-time exchange rates for various currencies.
#
# - Access historical exchange rates for a given date range.
#
# - Perform currency conversions, with results returned in a standardized, easy-to-parse format (usually JSON).
#
#
# No API key is required for basic use, making it a convenient option for quickly integrating currency-related data into applications or data analysis workflows.
#
# A key is required for what we want to do, and I have created one.

# %%
API_KEY = "2cf702f1ebad249cd268928ffe589052"

# %% [markdown]
# Set the url

# %%
url = "https://api.exchangerate.host/timeframe"
url_specific_date = "https://api.exchangerate.host/historical"

# %% [markdown]
# Set the parameters as a dictionary.
#
# If you don't remember what that is, look here:
#
# https://www.w3schools.com/python/python_dictionaries.asp

# %%
params = {
    "access_key": API_KEY,
    "start_date": "2023-12-15",
    "end_date": "2024-03-21"
}

specific_date_params = {
    "access_key": API_KEY,
    "date": "2023-12-15"
}

# %% [markdown]
# see how they look

# %%
params
# Out:
# {'access_key': '2cf702f1ebad249cd268928ffe589052',
#  'start_date': '2023-12-15',
#  'end_date': '2024-03-21'}

# %%
specific_date_params
# Out:
# {'access_key': '2cf702f1ebad249cd268928ffe589052', 'date': '2023-12-15'}

# %% [markdown]
# **Explanation of the code in the next cell** `response = requests.get(url, params=params)`
#
# - This line uses the Python **requests** library to send an HTTP **GET** request to `url`.
# - The optional `params` dictionary (e.g., `{'key': 'value'}`) is appended to the `url` as a query string (`?key=value`).
# - The method returns a `Response` object, stored in `response`, which contains:
#   - `response.status_code`: The HTTP status code (e.g., 200 for success).
#   - `response.text` or `response.content`: The body/content of the server’s response.
#   - `response.headers`: The response headers.
#
# By inspecting `response`, you can view the returned data and verify the status of your request.

# %%
response = requests.get(url,params=params)

# %%
response_specific_date = requests.get(url_specific_date, params= specific_date_params)

# %%
print(response.url)
# Out:
# https://api.exchangerate.host/timeframe?access_key=2cf702f1ebad249cd268928ffe589052&start_date=2023-12-15&end_date=2024-03-21

# %%
print(response_specific_date.url)
# Out:
# https://api.exchangerate.host/historical?access_key=2cf702f1ebad249cd268928ffe589052&date=2023-12-15

# %% [markdown]
# ### What does `data = response.json()` do?
#
# When you use the `requests` library in Python to make an HTTP request (for example, `requests.get()`), you receive a `Response` object. This response often contains data in JSON (JavaScript Object Notation) format.
#
# By calling:
#
# ```python
# data = response.json()
# ```
#
#
# you are:
#
# Parsing the JSON content of the response body into a Python object.
#
#
# The result is typically a dictionary (or list, depending on the JSON structure), which you can then manipulate, inspect, or process further in your code.
#
#
# In other words, .json() provides a convenient way to convert a JSON-formatted string into a native Python data structure.

# %%
data = response.json()

specific_date_data = response_specific_date.json()

# %% [markdown]
# **Try to figure out what other API do: look at the documentation**
# https://exchangerate.host/documentation

# %% [markdown]
# **Can oyu make sense of the URL below?**
# https://api.exchangerate.host/timeframe?access_key=2cf702f1ebad249cd268928ffe589052&start_date=2023-12-15&end_date=2024-03-21

# %%
data
# Out:
# {'success': True,
#  'terms': 'https://currencylayer.com/terms',
#  'privacy': 'https://currencylayer.com/privacy',
#  'timeframe': True,
#  'start_date': '2023-12-15',
#  'end_date': '2024-03-21',
#  'source': 'USD',
#  'quotes': {'2023-12-15': {'USDAED': 3.672604,
#    'USDAFN': 70.503991,
#    'USDALL': 93.950403,
#    'USDAMD': 405.303986,
#    'USDANG': 1.803798,
#    'USDAOA': 831.503981,
#    'USDARS': 791.340575,
#    'USDAUD': 1.492983,
#    'USDAWG': 1.8,
#    'USDAZN': 1.70397,
#    'USDBAM': 1.784652,
#    'USDBBD': 2.020786,
#    'USDBDT': 110.092162,
#    'USDBGN': 1.79455,
#    'USDBHD': 0.376991,
#    'USDBIF': 2855,
#    'USDBMD': 1,
#    'USDBND': 1.33017,
#    'USDBOB': 6.915714,
#    'USDBRL': 4.938104,
#    'USDBSD': 1.000867,
#    'USDBTC': 2.384802e-05,
#    'USDBTN': 83.073035,
#    'USDBWP': 13.335462,
#    'USDBYN': 3.297442,
#    'USDBYR': 19600,
#    'USDBZD': 2.017337,
#    'USDCAD': 1.33975,
#    'USDCDF': 2665.000362,
#    'USDCHF': 0.869504,
#    'USDCLF': 0.031563,
#    'USDCLP': 870.910396,
#    'USDCNY': 7.080504,
#    'USDCOP': 3943.25,
#    'USDCRC': 525.955599,
#    'USDCUC': 1,
#    'USDCUP': 26.5,
#    'USDCVE': 101.37504,
#    'USDCZK': 22.470504,
#    'USDDJF': 177.720394,
#    'USDDKK': 6.841904,
#    'USDDOP': 57.203886,
#    'USDDZD': 134.354046,
#    'USDEGP': 30.883175,
#    'USDERN': 15,
#    'USDETB': 55.870392,
#    'USDEUR': 0.916804,
#    'USDFJD': 2.247504,
#    'USDFKP': 0.783286,
#    'USDGBP': 0.788084,
#    'USDGEL': 2.690391,
#    'USDGGP': 0.783286,
#    'USDGHS': 12.04504,
#    'USDGIP': 0.783286,
#    'USDGMD': 66.99039,
#    'USDGNF': 8605.000355,
#    'USDGTQ': 7.826373,
#    'USDGYD': 209.570129,
#    'USDHKD': 7.80805,
#    'USDHNL': 24.740389,
#    'USDHRK': 6.98177,
#    'USDHTG': 132.247468,
#    'USDHUF': 351.160388,
#    'USDIDR': 15528.85,
#    'USDILS': 3.66445,
#    'USDIMP': 0.783286,
#    'USDINR': 83.04195,
#    'USDIQD': 1310,
#    'USDIRR': 42262.503818,
#    'USDISK': 138.130386,
#    'USDJEP': 0.783286,
#    'USDJMD': 155.742716,
#    'USDJOD': 0.709404,
#    'USDJPY': 142.12504,
#    'USDKES': 153.550385,
#    'USDKGS': 89.033304,
#    'USDKHR': 4118.000351,
#    'USDKMF': 447.503796,
#    'USDKPW': 899.973369,
#    'USDKRW': 1298.695039,
#    'USDKWD': 0.30761,
#    'USDKYD': 0.834071,
#    'USDKZT': 459.353414,
#    'USDLAK': 20660.000349,
#    'USDLBP': 15032.503779,
#    'USDLKR': 327.306241,
#    'USDLRD': 187.550382,
#    'USDLSL': 18.280382,
#    'USDLTL': 2.95274,
#    'USDLVL': 0.60489,
#    'USDLYD': 4.795039,
#    'USDMAD': 10.085504,
#    'USDMDL': 17.765145,
#    'USDMGA': 4580.000347,
#    'USDMKD': 56.441308,
#    'USDMMK': 2101.81493,
#    'USDMNT': 3446.328256,
#    'USDMOP': 8.046281,
#    'USDMRU': 39.552504,
#    'USDMUR': 44.030379,
#    'USDMVR': 15.403741,
#    'USDMWK': 1685.304039,
#    'USDMXN': 17.202039,
#    'USDMYR': 4.672504,
#    'USDMZN': 63.24995,
#    'USDNAD': 18.280377,
#    'USDNGN': 802.990377,
#    'USDNIO': 36.750377,
#    'USDNOK': 10.460204,
#    'USDNPR': 132.917849,
#    'USDNZD': 1.611085,
#    'USDOMR': 0.384961,
#    'USDPAB': 1.000776,
#    'USDPEN': 3.765039,
#    'USDPGK': 3.717039,
#    'USDPHP': 55.856039,
#    'USDPKR': 283.503704,
#    'USDPLN': 3.977082,
#    'USDPYG': 7319.031672,
#    'USDQAR': 3.641038,
#    'USDRON': 4.561904,
#    'USDRSD': 107.56881,
#    'USDRUB': 90.650373,
#    'USDRWF': 1257,
#    'USDSAR': 3.751291,
#    'USDSBD': 8.475185,
#    'USDSCR': 13.407867,
#    'USDSDG': 601.00034,
#    'USDSEK': 10.19015,
#    'USDSGD': 1.334038,
#    'USDSHP': 1.21675,
#    'USDSLE': 22.610203,
#    'USDSLL': 19750.000338,
#    'USDSOS': 571.000338,
#    'USDSRD': 37.698504,
#    'USDSTD': 20697.981008,
#    'USDSYP': 13001.879579,
#    'USDSZL': 18.28037,
#    'USDTHB': 34.88037,
#    'USDTJS': 10.934383,
#    'USDTMT': 3.51,
#    'USDTND': 3.066038,
#    'USDTOP': 2.34925,
#    'USDTRY': 28.982804,
#    'USDTTD': 6.795266,
#    'USDTWD': 31.362804,
#    'USDTZS': 2515.000336,
#    'USDUAH': 37.075672,
#    'USDUGX': 3773.120055,
#    'USDUYU': 40.01241,
#    'USDUZS': 12375.000335,
#    'USDVEF': 3558256.748513,
#    'USDVES': 35.581695,
#    'USDVND': 24275,
#    'USDVUV': 119.093307,
#    'USDWST': 2.711072,
#    'USDXAF': 598.550063,
#    'USDXAG': 0.041887,
#    'USDXAU': 0.000495,
#    'USDXCD': 2.70255,
#    'USDXDR': 0.753775,
#    'USDXOF': 602.5036,
#    'USDXPF': 108.703597,
#    'USDYER': 250.375037,
#    'USDZAR': 18.344504,
#    'USDZMK': 9001.203591,
#    'USDZMW': 24.895978,
#    'USDZWL': 321.999592},
#   '2023-12-16': {'USDAED': 3.672704,
#    'USDAFN': 70.232366,
#    'USDALL': 95.329758,
#    'USDAMD': 406.709748,
#    'USDANG': 1.811999,
#    'USDAOA': 831.503981,
#    'USDARS': 791.340575,
#    'USDAUD': 1.492983,
#    'USDAWG': 1.8,
#    'USDAZN': 1.70397,
#    'USDBAM': 1.792749,
#    'USDBBD': 2.029974,
#    'USDBDT': 110.591686,
#    'USDBGN': 1.792749,
#    'USDBHD': 0.379027,
#    'USDBIF': 2861.909345,
#    'USDBMD': 1,
#    'USDBND': 1.336267,
#    'USDBOB': 6.947156,
#    'USDBRL': 4.942573,
#    'USDBSD': 1.005454,
#    'USDBTC': 2.3683373e-05,
#    'USDBTN': 83.451487,
#    'USDBWP': 13.396581,
#    'USDBYN': 3.312434,
#    'USDBYR': 19600,
#    'USDBZD': 2.026582,
#    'USDCAD': 1.33975,
#    'USDCDF': 2665.000362,
#    'USDCHF': 0.86902,
#    'USDCLF': 0.031563,
#    'USDCLP': 870.333196,
#    'USDCNY': 7.080504,
#    'USDCOP': 3991.933636,
#    'USDCRC': 528.346854,
#    'USDCUC': 1,
#    'USDCUP': 26.5,
#    'USDCVE': 101.07246,
#    'USDCZK': 22.470404,
#    'USDDJF': 179.00912,
#    'USDDKK': 6.841904,
#    'USDDOP': 57.518676,
#    'USDDZD': 134.34704,
#    'USDEGP': 30.883175,
#    'USDERN': 15,
#    'USDETB': 56.556762,
#    'USDEUR': 0.916804,
#    'USDFJD': 2.21195,
#    'USDFKP': 0.786872,
#    'USDGBP': 0.788084,
#    'USDGEL': 2.690391,
#    'USDGGP': 0.786872,
#    'USDGHS': 12.110546,
#    'USDGIP': 0.786872,
#    'USDGMD': 66.99039,
#    'USDGNF': 8643.842523,
#    'USDGTQ': 7.861955,
#    'USDGYD': 210.522939,
#    'USDHKD': 7.807304,
#    'USDHNL': 24.79307,
#    'USDHRK': 6.98177,
#    'USDHTG': 132.847518,
#    'USDHUF': 351.160388,
#    'USDIDR': 15528.85,
#    'USDILS': 3.66445,
#    'USDIMP': 0.786872,
#    'USDINR': 83.04195,
#    'USDIQD': 1317.108942,
#    'USDIRR': 42262.503818,
#    'USDISK': 138.130386,
#    'USDJEP': 0.786872,
#    'USDJMD': 156.4508,
#    'USDJOD': 0.709404,
#    'USDJPY': 142.11504,
#    'USDKES': 155.534167,
#    'USDKGS': 89.033304,
#    'USDKHR': 4132.178377,
#    'USDKMF': 447.503796,
#    'USDKPW': 900.004127,
#    'USDKRW': 1298.695039,
#    'USDKWD': 0.30761,
#    'USDKYD': 0.837894,
#    'USDKZT': 461.441863,
#    'USDLAK': 20680.141161,
#    'USDLBP': 15111.324992,
#    'USDLKR': 328.786837,
#    'USDLRD': 187.550382,
#    'USDLSL': 18.280382,
#    'USDLTL': 2.95274,
#    'USDLVL': 0.60489,
#    'USDLYD': 4.826986,
#    'USDMAD': 10.146936,
#    'USDMDL': 17.845914,
#    'USDMGA': 4596.910949,
#    'USDMKD': 56.473716,
#    'USDMMK': 2111.370824,
#    'USDMNT': 3440.212284,
#    'USDMOP': 8.082864,
#    'USDMRU': 39.552504,
#    'USDMUR': 44.030379,
#    'USDMVR': 15.403741,
#    'USDMWK': 1692.469866,
#    'USDMXN': 17.202504,
#    'USDMYR': 4.672504,
#    'USDMZN': 63.24995,
#    'USDNAD': 18.280377,
#    'USDNGN': 802.990377,
#    'USDNIO': 36.79362,
#    'USDNOK': 10.460204,
#    'USDNPR': 133.52216,
#    'USDNZD': 1.611085,
#    'USDOMR': 0.38495,
#    'USDPAB': 1.005362,
#    'USDPEN': 3.786791,
#    'USDPGK': 3.749026,
#    'USDPHP': 55.856039,
#    'USDPKR': 281.313259,
#    'USDPLN': 3.955727,
#    'USDPYG': 7352.307622,
#    'USDQAR': 3.641038,
#    'USDRON': 4.561904,
#    'USDRSD': 107.415555,
#    'USDRUB': 90.650373,
#    'USDRWF': 1258.169485,
#    'USDSAR': 3.751304,
#    'USDSBD': 8.475185,
#    'USDSCR': 13.407038,
#    'USDSDG': 601.00034,
#    'USDSEK': 10.19015,
#    'USDSGD': 1.333904,
#    'USDSHP': 1.21675,
#    'USDSLE': 22.649439,
#    'USDSLL': 19750.000338,
#    'USDSOS': 571.000338,
#    'USDSRD': 37.698504,
#    'USDSTD': 20697.981008,
#    'USDSYP': 13001.834885,
#    'USDSZL': 18.22815,
#    'USDTHB': 34.88037,
#    'USDTJS': 10.984096,
#    'USDTMT': 3.51,
#    'USDTND': 3.066038,
#    'USDTOP': 2.34925,
#    'USDTRY': 28.982804,
#    'USDTTD': 6.826161,
#    'USDTWD': 31.362804,
#    'USDTZS': 2518.538888,
#    'USDUAH': 37.244237,
#    'USDUGX': 3790.274531,
#    'USDUYU': 40.194326,
#    'USDUZS': 12444.200009,
#    'USDVEF': 3558665.395252,
#    'USDVES': 35.581695,
#    'USDVND': 24275,
#    'USDVUV': 118.755768,
#    'USDWST': 2.717306,
#    'USDXAF': 601.271369,
#    'USDXAG': 0.041887,
#    'USDXAU': 0.000495,
#    'USDXCD': 2.70255,
#    'USDXDR': 0.75723,
#    'USDXOF': 601.271369,
#    'USDXPF': 108.703597,
#    'USDYER': 250.375037,
#    'USDZAR': 18.46804,
#    'USDZMK': 9001.203591,
#    'USDZMW': 25.009395,
#    'USDZWL': 321.999592},
#   '2023-12-17': {'USDAED': 3.672498,
#    'USDAFN': 69.884933,
#    'USDALL': 94.401877,
#    'USDAMD': 400.242504,
#    'USDANG': 1.7873,
#    'USDAOA': 828.792169,
#    'USDARS': 792.382849,
#    'USDAUD': 1.49274,
#    'USDAWG': 1.8,
#    'USDAZN': 1.699684,
#    'USDBAM': 1.792749,
#    'USDBBD': 2.029974,
#    'USDBDT': 110.591686,
#    'USDBGN': 1.792749,
#    'USDBHD': 0.379027,
#    'USDBIF': 2861.909345,
#    'USDBMD': 1,
#    'USDBND': 1.336267,
#    'USDBOB': 6.947156,
#    'USDBRL': 4.942573,
#    'USDBSD': 1.005454,
#    'USDBTC': 2.4158662e-05,
#    'USDBTN': 83.451487,
#    'USDBWP': 13.396581,
#    'USDBYN': 3.312434,
#    'USDBYR': 19600,
#    'USDBZD': 2.026582,
#    'USDCAD': 1.337945,
#    'USDCDF': 2665.000153,
#    'USDCHF': 0.87071,
#    'USDCLF': 0.031563,
#    'USDCLP': 870.333196,
#    'USDCNY': 7.080501,
#    'USDCOP': 3991.933636,
#    'USDCRC': 528.346854,
#    'USDCUC': 1,
#    'USDCUP': 26.5,
#    'USDCVE': 101.07246,
#    'USDCZK': 22.46765,
#    'USDDJF': 179.00912,
#    'USDDKK': 6.84167,
#    'USDDOP': 57.518676,
#    'USDDZD': 134.347054,
#    'USDEGP': 30.923851,
#    'USDERN': 15,
#    'USDETB': 56.556762,
#    'USDEUR': 0.917855,
#    'USDFJD': 2.21195,
#    'USDFKP': 0.788389,
#    'USDGBP': 0.789113,
#    'USDGEL': 2.690041,
#    'USDGGP': 0.788389,
#    'USDGHS': 12.110546,
#    'USDGIP': 0.788389,
#    'USDGMD': 66.990312,
#    'USDGNF': 8643.842523,
#    'USDGTQ': 7.861955,
#    'USDGYD': 210.522939,
#    'USDHKD': 7.80308,
#    'USDHNL': 24.79307,
#    'USDHRK': 6.98177,
#    'USDHTG': 132.847518,
#    'USDHUF': 351.034972,
#    'USDIDR': 15528.85,
#    'USDILS': 3.666097,
#    'USDIMP': 0.788389,
#    'USDINR': 83.04195,
#    'USDIQD': 1317.108942,
#    'USDIRR': 42262.497406,
#    'USDISK': 138.13006,
#    'USDJEP': 0.788389,
#    'USDJMD': 156.4508,
#    'USDJOD': 0.709403,
#    'USDJPY': 142.296499,
#    'USDKES': 155.534167,
#    'USDKGS': 89.033296,
#    'USDKHR': 4132.178377,
#    'USDKMF': 447.504465,
#    'USDKPW': 900,
#    'USDKRW': 1298.694975,
#    'USDKWD': 0.307609,
#    'USDKYD': 0.837894,
#    'USDKZT': 461.441863,
#    'USDLAK': 20680.141161,
#    'USDLBP': 15111.324992,
#    'USDLKR': 328.786837,
#    'USDLRD': 187.550663,
#    'USDLSL': 18.279653,
#    'USDLTL': 2.95274,
#    'USDLVL': 0.60489,
#    'USDLYD': 4.826986,
#    'USDMAD': 10.146936,
#    'USDMDL': 17.845914,
#    'USDMGA': 4596.910949,
#    'USDMKD': 56.473716,
#    'USDMMK': 2111.370824,
#    'USDMNT': 3420.784747,
#    'USDMOP': 8.082864,
#    'USDMRU': 39.552502,
#    'USDMUR': 44.030072,
#    'USDMVR': 15.385341,
#    'USDMWK': 1692.469866,
#    'USDMXN': 17.22839,
#    'USDMYR': 4.672501,
#    'USDMZN': 63.24995,
#    'USDNAD': 18.27986,
#    'USDNGN': 802.990161,
#    'USDNIO': 36.79362,
#    'USDNOK': 10.48875,
#    'USDNPR': 133.52216,
#    'USDNZD': 1.61035,
#    'USDOMR': 0.38495,
#    'USDPAB': 1.005362,
#    'USDPEN': 3.786791,
#    'USDPGK': 3.749026,
#    'USDPHP': 55.855986,
#    'USDPKR': 281.313259,
#    'USDPLN': 3.977797,
#    'USDPYG': 7352.307622,
#    'USDQAR': 3.640985,
#    'USDRON': 4.55274,
#    'USDRSD': 107.415555,
#    'USDRUB': 90.64975,
#    'USDRWF': 1258.169485,
#    'USDSAR': 3.751301,
#    'USDSBD': 8.475185,
#    'USDSCR': 13.406956,
#    'USDSDG': 600.999924,
#    'USDSEK': 10.28415,
#    'USDSGD': 1.33328,
#    'USDSHP': 1.21675,
#    'USDSLE': 22.644971,
#    'USDSLL': 19750.000263,
#    'USDSOS': 570.999913,
#    'USDSRD': 37.698499,
#    'USDSTD': 20697.981008,
#    'USDSYP': 13001.784107,
#    'USDSZL': 18.22815,
#    'USDTHB': 34.980984,
#    'USDTJS': 10.984096,
#    'USDTMT': 3.51,
#    'USDTND': 3.065965,
#    'USDTOP': 2.34925,
#    'USDTRY': 28.93131,
#    'USDTTD': 6.826161,
#    'USDTWD': 31.362801,
#    'USDTZS': 2518.538888,
#    'USDUAH': 37.244237,
#    'USDUGX': 3790.274531,
#    'USDUYU': 40.194326,
#    'USDUZS': 12444.200009,
#    'USDVEF': 3560408.718743,
#    'USDVES': 35.581695,
#    'USDVND': 24275,
#    'USDVUV': 117.828633,
#    'USDWST': 2.683112,
#    'USDXAF': 601.271369,
#    'USDXAG': 0.042126,
#    'USDXAU': 0.000496,
#    'USDXCD': 2.70255,
#    'USDXDR': 0.75723,
#    'USDXOF': 601.271369,
#    'USDXPF': 108.690979,
#    'USDYER': 250.375015,
#    'USDZAR': 18.335703,
#    'USDZMK': 9001.197543,
#    'USDZMW': 25.009395,
#    'USDZWL': 321.999592},
#   '2023-12-18': {'USDAED': 3.672699,
#    'USDAFN': 69.498113,
#    'USDALL': 94.834063,
#    'USDAMD': 405.266727,
#    'USDANG': 1.802014,
#    'USDAOA': 828.794964,
#    'USDARS': 802.625043,
#    'USDAUD': 1.491775,
#    'USDAWG': 1.8025,
#    'USDAZN': 1.710419,
#    'USDBAM': 1.792027,
#    'USDBBD': 2.01894,
#    'USDBDT': 109.739784,
#    'USDBGN': 1.790899,
#    'USDBHD': 0.376892,
#    'USDBIF': 2858,
#    'USDBMD': 1,
#    'USDBND': 1.331727,
#    'USDBOB': 6.909601,
#    'USDBRL': 4.897402,
#    'USDBSD': 0.99994,
#    'USDBTC': 2.3450967e-05,
#    'USDBTN': 83.038144,
#    'USDBWP': 13.439742,
#    'USDBYN': 3.293857,
#    'USDBYR': 19600,
#    'USDBZD': 2.015549,
#    'USDCAD': 1.339835,
#    'USDCDF': 2699.999988,
#    'USDCHF': 0.86719,
#    'USDCLF': 0.031684,
#    'USDCLP': 874.249766,
#    'USDCNY': 7.132966,
#    'USDCOP': 3934.5,
#    'USDCRC': 524.102292,
#    'USDCUC': 1,
#    'USDCUP': 26.5,
#    'USDCVE': 101.396776,
#    'USDCZK': 22.443803,
#    'USDDJF': 177.720419,
#    'USDDKK': 6.82452,
#    'USDDOP': 57.249812,
#    'USDDZD': 134.543624,
#    'USDEGP': 30.899229,
#    'USDERN': 15,
#    'USDETB': 56.253276,
#    'USDEUR': 0.915475,
#    'USDFJD': 2.2154,
#    'USDFKP': 0.788577,
#    'USDGBP': 0.790451,
#    'USDGEL': 2.68988,
#    'USDGGP': 0.788577,
#    'USDGHS': 12.030405,
#    'USDGIP': 0.788577,
#    'USDGMD': 67.375017,
#    'USDGNF': 8610.000208,
#    'USDGTQ': 7.819386,
#    'USDGYD': 209.193865,
#    'USDHKD': 7.79515,
#    'USDHNL': 24.657547,
#    'USDHRK': 6.98177,
#    'USDHTG': 132.036486,
#    'USDHUF': 352.070065,
#    'USDIDR': 15452,
#    'USDILS': 3.665102,
#    'USDIMP': 0.788577,
#    'USDINR': 83.11145,
#    'USDIQD': 1308.911317,
#    'USDIRR': 42275.00017,
#    'USDISK': 137.960282,
#    'USDJEP': 0.788577,
#    'USDJMD': 155.326284,
#    'USDJOD': 0.709302,
#    'USDJPY': 142.7235,
#    'USDKES': 154.14999,
#    'USDKGS': 89.049446,
#    'USDKHR': 4113.999894,
#    'USDKMF': 450.534498,
#    'USDKPW': 899.999954,
#    'USDKRW': 1303.929721,
#    'USDKWD': 0.30759,
#    'USDKYD': 0.833257,
#    'USDKZT': 458.911547,
#    'USDLAK': 20608.770547,
#    'USDLBP': 15028.58766,
#    'USDLKR': 326.985014,
#    'USDLRD': 187.549977,
#    'USDLSL': 18.280188,
#    'USDLTL': 2.95274,
#    'USDLVL': 0.60489,
#    'USDLYD': 4.798424,
#    'USDMAD': 10.11096,
#    'USDMDL': 17.643717,
#    'USDMGA': 4574.999727,
#    'USDMKD': 56.331,
#    'USDMMK': 2099.818578,
#    'USDMNT': 3419.208923,
#    'USDMOP': 8.033407,
#    'USDMRU': 39.549793,
#    'USDMUR': 44.601675,
#    'USDMVR': 15.397165,
#    'USDMWK': 1683.19009,
#    'USDMXN': 17.165198,
#    'USDMYR': 4.693969,
#    'USDMZN': 63.24995,
#    'USDNAD': 18.280105,
#    'USDNGN': 789.909905,
#    'USDNIO': 36.595534,
#    'USDNOK': 10.399595,
#    'USDNPR': 132.860847,
#    'USDNZD': 1.609475,
#    'USDOMR': 0.38494,
#    'USDPAB': 0.99994,
#    'USDPEN': 3.761075,
#    'USDPGK': 3.778702,
#    'USDPHP': 55.773504,
#    'USDPKR': 279.723103,
#    'USDPLN': 3.958987,
#    'USDPYG': 7307.262365,
#    'USDQAR': 3.641012,
#    'USDRON': 4.550901,
#    'USDRSD': 107.280967,
#    'USDRUB': 90.525003,
#    'USDRWF': 1252.359398,
#    'USDSAR': 3.751142,
#    'USDSBD': 8.475185,
#    'USDSCR': 13.398334,
#    'USDSDG': 600.99964,
#    'USDSEK': 10.220101,
#    'USDSGD': 1.33217,
#    'USDSHP': 1.21675,
#    'USDSLE': 22.644964,
#    'USDSLL': 19750.000289,
#    'USDSOS': 570.999662,
#    'USDSRD': 37.481501,
#    'USDSTD': 20697.981008,
#    'USDSYP': 13001.850253,
#    'USDSZL': 18.443875,
#    'USDTHB': 34.949787,
#    'USDTJS': 10.918928,
#    'USDTMT': 3.51,
#    'USDTND': 3.066024,
#    'USDTOP': 2.35035,
#    'USDTRY': 29.05631,
#    'USDTTD': 6.789569,
#    'USDTWD': 31.389979,
#    'USDTZS': 2505.000083,
#    'USDUAH': 37.207755,
#    'USDUGX': 3771.423859,
#    'USDUYU': 39.646326,
#    'USDUZS': 12385.010079,
#    'USDVEF': 3556893.77218,
#    'USDVES': 35.581695,
#    'USDVND': 24360,
#    'USDVUV': 117.828633,
#    'USDWST': 2.683112,
#    'USDXAF': 601.042731,
#    'USDXAG': 0.041998,
#    'USDXAU': 0.000493,
#    'USDXCD': 2.70255,
#    'USDXDR': 0.745763,
#    'USDXOF': 601.023456,
#    'USDXPF': 108.703814,
#    'USDYER': 250.374986,
#    'USDZAR': 18.593019,
#    'USDZMK': 9001.197294,
#    'USDZMW': 24.997709,
#    'USDZWL': 321.999592},
#   '2023-12-19': {'USDAED': 3.672698,
#    'USDAFN': 69.999892,
#    'USDALL': 94.75013,
#    'USDAMD': 405.809928,
#    'USDANG': 1.800824,
#    'USDAOA': 832.498357,
#    'USDARS': 803.17132,
#    'USDAUD': 1.479071,
#    'USDAWG': 1.8,
#    'USDAZN': 1.710555,
#    'USDBAM': 1.786731,
#    'USDBBD': 2.017385,
#    'USDBDT': 109.662626,
#    'USDBGN': 1.781105,
#    'USDBHD': 0.376927,
#    'USDBIF': 2861,
#    'USDBMD': 1,
#    'USDBND': 1.331281,
#    'USDBOB': 6.904679,
#    'USDBRL': 4.86797,
#    'USDBSD': 0.999146,
#    'USDBTC': 2.3657587e-05,
#    'USDBTN': 83.126839,
#    'USDBWP': 13.447098,
#    'USDBYN': 3.291934,
#    'USDBYR': 19600,
#    'USDBZD': 2.013959,
#    'USDCAD': 1.333575,
#    'USDCDF': 2854.999711,
#    'USDCHF': 0.860535,
#    'USDCLF': 0.031271,
#    'USDCLP': 862.870175,
#    'USDCNY': 7.077601,
#    'USDCOP': 3943,
#    'USDCRC': 523.644868,
#    'USDCUC': 1,
#    'USDCUP': 26.5,
#    'USDCVE': 100.849956,
#    'USDCZK': 22.3404,
#    'USDDJF': 177.719794,
#    'USDDKK': 6.790701,
#    'USDDOP': 57.30174,
#    'USDDZD': 134.458764,
#    'USDEGP': 30.921798,
#    'USDERN': 15,
#    'USDETB': 56.249493,
#    'USDEUR': 0.91069,
#    'USDFJD': 2.20565,
#    'USDFKP': 0.791638,
#    'USDGBP': 0.785435,
#    'USDGEL': 2.685033,
#    'USDGGP': 0.791638,
#    'USDGHS': 12.029862,
#    'USDGIP': 0.791638,
#    'USDGMD': 67.349749,
#    'USDGNF': 8604.999813,
#    'USDGTQ': 7.813742,
#    'USDGYD': 209.205021,
#    'USDHKD': 7.79965,
#    'USDHNL': 24.71978,
#    'USDHRK': 6.98177,
#    'USDHTG': 131.943525,
#    'USDHUF': 350.22997,
#    'USDIDR': 15462,
#    'USDILS': 3.654096,
#    'USDIMP': 0.791638,
#    'USDINR': 83.091849,
#    'USDIQD': 1310,
#    'USDIRR': 42262.499569,
#    'USDISK': 137.059923,
#    'USDJEP': 0.791638,
#    'USDJMD': 154.979628,
#    'USDJOD': 0.709303,
#    'USDJPY': 143.891996,
#    'USDKES': 154.552774,
#    'USDKGS': 89.016705,
#    'USDKHR': 4119.99976,
#    'USDKMF': 448.624999,
#    'USDKPW': 900.004713,
#    'USDKRW': 1298.339616,
#    'USDKWD': 0.30754,
#    'USDKYD': 0.832679,
#    'USDKZT': 457.369936,
#    'USDLAK': 20600.000188,
#    'USDLBP': 15035.000035,
#    'USDLKR': 326.985708,
#    'USDLRD': 188.301579,
#    'USDLSL': 18.570462,
#    'USDLTL': 2.95274,
#    'USDLVL': 0.60489,
#    'USDLYD': 4.80123,
#    'USDMAD': 10.107503,
#    'USDMDL': 17.535926,
#    'USDMGA': 4584.999807,
#    'USDMKD': 56.036249,
#    'USDMMK': 2098.185738,
#    'USDMNT': 3436.613816,
#    'USDMOP': 8.026968,
#    'USDMRU': 39.550158,
#    'USDMUR': 44.159828,
#    'USDMVR': 15.349667,
#    'USDMWK': 1683.000193,
#    'USDMXN': 17.0748,
#    'USDMYR': 4.684498,
#    'USDMZN': 63.24995,
#    'USDNAD': 18.570385,
#    'USDNGN': 802.504229,
#    'USDNIO': 36.749931,
#    'USDNOK': 10.27121,
#    'USDNPR': 132.998374,
#    'USDNZD': 1.59493,
#    'USDOMR': 0.384945,
#    'USDPAB': 0.999214,
#    'USDPEN': 3.746972,
#    'USDPGK': 3.618031,
#    'USDPHP': 55.714996,
#    'USDPKR': 283.349823,
#    'USDPLN': 3.938998,
#    'USDPYG': 7317.674788,
#    'USDQAR': 3.64075,
#    'USDRON': 4.527699,
#    'USDRSD': 106.727993,
#    'USDRUB': 90.475022,
#    'USDRWF': 1259,
#    'USDSAR': 3.751059,
#    'USDSBD': 8.440171,
#    'USDSCR': 13.467826,
#    'USDSDG': 601.000103,
#    'USDSEK': 10.16096,
#    'USDSGD': 1.328796,
#    'USDSHP': 1.21675,
#    'USDSLE': 22.829982,
#    'USDSLL': 19750.000446,
#    'USDSOS': 570.999957,
#    'USDSRD': 37.291502,
#    'USDSTD': 20697.981008,
#    'USDSYP': 13001.978573,
#    'USDSZL': 18.570346,
#    'USDTHB': 34.839882,
#    'USDTJS': 10.905669,
#    'USDTMT': 3.5,
#    'USDTND': 3.095983,
#    'USDTOP': 2.349803,
#    'USDTRY': 29.09351,
#    'USDTTD': 6.782169,
#    'USDTWD': 31.284975,
#    'USDTZS': 2515.000292,
#    'USDUAH': 37.318619,
#    'USDUGX': 3764.742424,
#    'USDUYU': 39.372596,
#    'USDUZS': 12390.000293,
#    'USDVEF': 3567583.099981,
#    'USDVES': 35.609458,
#    'USDVND': 24357.5,
#    'USDVUV': 118.810035,
#    'USDWST': 2.712472,
#    'USDXAF': 599.233552,
#    'USDXAG': 0.041577,
#    'USDXAU': 0.00049,
#    'USDXCD': 2.70255,
#    'USDXDR': 0.745163,
#    'USDXOF': 601.000069,
#    'USDXPF': 112.625032,
#    'USDYER': 249.894993,
#    'USDZAR': 18.340097,
#    'USDZMK': 9001.199549,
#    'USDZMW': 25.129269,
#    'USDZWL': 321.999592},
#   '2023-12-20': {'USDAED': 3.672501,
#    'USDAFN': 69.773173,
#    'USDALL': 94.549729,
#    'USDAMD': 404.483698,
#    'USDANG': 1.802256,
#    'USDAOA': 831.501509,
#    'USDARS': 803.721296,
#    'USDAUD': 1.48382,
#    'USDAWG': 1.8025,
#    'USDAZN': 1.697767,
#    'USDBAM': 1.78816,
#    'USDBBD': 2.019118,
#    'USDBDT': 109.750857,
#    'USDBGN': 1.786713,
#    'USDBHD': 0.376879,
#    'USDBIF': 2860,
#    'USDBMD': 1,
#    'USDBND': 1.33028,
#    'USDBOB': 6.910235,
#    'USDBRL': 4.916097,
#    'USDBSD': 0.999959,
#    'USDBTC': 2.2920776e-05,
#    'USDBTN': 83.175343,
#    'USDBWP': 13.405196,
#    'USDBYN': 3.294659,
#    'USDBYR': 19600,
#    'USDBZD': 2.015716,
#    'USDCAD': 1.33589,
#    'USDCDF': 2856.000223,
#    'USDCHF': 0.862665,
#    'USDCLF': 0.031551,
#    'USDCLP': 870.572936,
#    'USDCNY': 7.135098,
#    'USDCOP': 3941.63,
#    'USDCRC': 522.793351,
#    'USDCUC': 1,
#    'USDCUP': 26.5,
#    'USDCVE': 100.875031,
#    'USDCZK': 22.384007,
#    'USDDJF': 177.72025,
#    'USDDKK': 6.813485,
#    'USDDOP': 57.549873,
#    'USDDZD': 134.400168,
#    'USDEGP': 30.904901,
#    'USDERN': 15,
#    'USDETB': 56.150274,
#    'USDEUR': 0.913701,
#    'USDFJD': 2.208995,
#    'USDFKP': 0.784249,
#    'USDGBP': 0.791125,
#    'USDGEL': 2.684987,
#    'USDGGP': 0.784249,
#    'USDGHS': 12.030222,
#    'USDGIP': 0.784249,
#    'USDGMD': 67.375044,
#    'USDGNF': 8610.00003,
#    'USDGTQ': 7.819957,
#    'USDGYD': 209.382486,
#    'USDHKD': 7.807215,
#    'USDHNL': 24.703608,
#    'USDHRK': 6.98177,
#    'USDHTG': 132.051493,
#    'USDHUF': 351.02499,
#    'USDIDR': 15606,
#    'USDILS': 3.627101,
#    'USDIMP': 0.784249,
#    'USDINR': 83.26745,
#    'USDIQD': 1310,
#    'USDIRR': 42274.999827,
#    'USDISK': 137.349693,
#    'USDJEP': 0.784249,
#    'USDJMD': 155.062148,
#    'USDJOD': 0.709399,
#    'USDJPY': 143.526504,
#    'USDKES': 154.999981,
#    'USDKGS': 88.865602,
#    'USDKHR': 4115.000384,
#    'USDKMF': 449.124993,
#    'USDKPW': 900.016768,
#    'USDKRW': 1299.930322,
#    'USDKWD': 0.30759,
#    'USDKYD': 0.833368,
#    'USDKZT': 456.260172,
#    'USDLAK': 20612.508216,
#    'USDLBP': 15075.000342,
#    'USDLKR': 327.096352,
#    'USDLRD': 188.350202,
#    'USDLSL': 18.269873,
#    'USDLTL': 2.95274,
#    'USDLVL': 0.604891,
#    'USDLYD': 4.805027,
#    'USDMAD': 10.042502,
#    'USDMDL': 17.450217,
#    'USDMGA': 4602.504982,
#    'USDMKD': 56.296655,
#    'USDMMK': 2100.013257,
#    'USDMNT': 3432.669426,
#    'USDMOP': 8.040302,
#    'USDMRU': 39.550029,
#    'USDMUR': 43.949849,
#    'USDMVR': 15.404798,
#    'USDMWK': 1684.599356,
#    'USDMXN': 17.13635,
#    'USDMYR': 4.658028,
#    'USDMZN': 63.24995,
#    'USDNAD': 18.269902,
#    'USDNGN': 824.999961,
#    'USDNIO': 36.792332,
#    'USDNOK': 10.345701,
#    'USDNPR': 133.080988,
#    'USDNZD': 1.599135,
#    'USDOMR': 0.384956,
#    'USDPAB': 1.000041,
#    'USDPEN': 3.72701,
#    'USDPGK': 3.61775,
#    'USDPHP': 55.877979,
#    'USDPKR': 283.104962,
#    'USDPLN': 3.970197,
#    'USDPYG': 7344.423568,
#    'USDQAR': 3.64075,
#    'USDRON': 4.541803,
#    'USDRSD': 107.067514,
#    'USDRUB': 90.090229,
#    'USDRWF': 1257,
#    'USDSAR': 3.75077,
#    'USDSBD': 8.418851,
#    'USDSCR': 13.439696,
#    'USDSDG': 600.999859,
#    'USDSEK': 10.172955,
#    'USDSGD': 1.33182,
#    'USDSHP': 1.26455,
#    'USDSLE': 22.71552,
#    'USDSLL': 19749.999836,
#    'USDSOS': 571.000371,
#    'USDSRD': 37.261502,
#    'USDSTD': 20697.981008,
#    'USDSYP': 13002.184887,
#    'USDSZL': 18.420009,
#    'USDTHB': 34.979499,
#    'USDTJS': 10.930111,
#    'USDTMT': 3.51,
#    'USDTND': 3.089499,
#    'USDTOP': 2.34097,
#    'USDTRY': 29.130503,
#    'USDTTD': 6.796862,
#    'USDTWD': 31.324958,
#    'USDTZS': 2514.999822,
#    'USDUAH': 37.622137,
#    'USDUGX': 3759.508484,
#    'USDUYU': 39.369143,
#    'USDUZS': 12399.999866,
#    'USDVEF': 3560443.561543,
#    'USDVES': 35.671998,
#    'USDVND': 24345,
#    'USDVUV': 118.51828,
#    'USDWST': 2.709374,
#    'USDXAF': 599.729373,
#    'USDXAG': 0.041376,
#    'USDXAU': 0.000492,
#    'USDXCD': 2.70255,
#    'USDXDR': 0.745881,
#    'USDXOF': 598.499211,
#    'USDXPF': 109.291204,
#    'USDYER': 250.349657,
#    'USDZAR': 18.30005,
#    'USDZMK': 9001.194672,
#    'USDZMW': 25.300346,
#    'USDZWL': 321.999592},
#   '2023-12-21': {'USDAED': 3.672701,
#    'USDAFN': 70.502706,
#    'USDALL': 94.29823,
#    'USDAMD': 405.389412,
#    'USDANG': 1.801539,
#    'USDAOA': 831.500812,
#    'USDARS': 804.228622,
#    'USDAUD': 1.471562,
#    'USDAWG': 1.8,
#    'USDAZN': 1.695079,
#    'USDBAM': 1.780784,
#    'USDBBD': 2.018629,
#    'USDBDT': 109.726117,
#    'USDBGN': 1.776698,
#    'USDBHD': 0.376921,
#    'USDBIF': 2861,
#    'USDBMD': 1,
#    'USDBND': 1.328762,
#    'USDBOB': 6.932496,
#    'USDBRL': 4.883304,
#    'USDBSD': 0.999745,
#    'USDBTC': 2.2792338e-05,
#    'USDBTN': 83.233737,
#    'USDBWP': 13.375036,
#    'USDBYN': 3.293907,
#    'USDBYR': 19600,
#    'USDBZD': 2.015151,
#    'USDCAD': 1.32835,
#    'USDCDF': 2859.999969,
#    'USDCHF': 0.856325,
#    'USDCLF': 0.031862,
#    'USDCLP': 879.17979,
#    'USDCNY': 7.139498,
#    'USDCOP': 3946.5,
#    'USDCRC': 522.281397,
#    'USDCUC': 1,
#    'USDCUP': 26.5,
#    'USDCVE': 100.80212,
#    'USDCZK': 22.335503,
#    'USDDJF': 177.499077,
#    'USDDKK': 6.774297,
#    'USDDOP': 57.600085,
#    'USDDZD': 134.494334,
#    'USDEGP': 30.900799,
#    'USDERN': 15,
#    'USDETB': 56.159669,
#    'USDEUR': 0.90861,
#    'USDFJD': 2.221799,
#    'USDFKP': 0.789969,
#    'USDGBP': 0.788455,
#    'USDGEL': 2.690412,
#    'USDGGP': 0.789969,
#    'USDGHS': 12.030098,
#    'USDGIP': 0.789969,
#    'USDGMD': 67.350182,
#    'USDGNF': 8554.999705,
#    'USDGTQ': 7.811917,
#    'USDGYD': 209.330171,
#    'USDHKD': 7.80995,
#    'USDHNL': 24.750201,
#    'USDHRK': 6.98177,
#    'USDHTG': 131.925665,
#    'USDHUF': 347.325019,
#    'USDIDR': 15446,
#    'USDILS': 3.62504,
#    'USDIMP': 0.789969,
#    'USDINR': 83.17185,
#    'USDIQD': 1310,
#    'USDIRR': 42262.500564,
#    'USDISK': 136.560015,
#    'USDJEP': 0.789969,
#    'USDJMD': 155.466929,
#    'USDJOD': 0.709398,
#    'USDJPY': 142.071026,
#    'USDKES': 155.750024,
#    'USDKGS': 88.885096,
#    'USDKHR': 4107.000138,
#    'USDKMF': 447.296651,
#    'USDKPW': 900.01887,
#    'USDKRW': 1294.259849,
#    'USDKWD': 0.30725,
#    'USDKYD': 0.833151,
#    'USDKZT': 460.236378,
#    'USDLAK': 20625.000149,
#    'USDLBP': 15062.507781,
#    'USDLKR': 324.871386,
#    'USDLRD': 188.349882,
#    'USDLSL': 18.360172,
#    'USDLTL': 2.95274,
#    'USDLVL': 0.60489,
#    'USDLYD': 4.80199,
#    'USDMAD': 9.959865,
#    'USDMDL': 17.438208,
#    'USDMGA': 4585.000466,
#    'USDMKD': 56.042677,
#    'USDMMK': 2099.541084,
#    'USDMNT': 3437.900656,
#    'USDMOP': 8.043778,
#    'USDMRU': 39.579701,
#    'USDMUR': 43.979952,
#    'USDMVR': 15.349944,
#    'USDMWK': 1681.999703,
#    'USDMXN': 17.03455,
#    'USDMYR': 4.655501,
#    'USDMZN': 63.24995,
#    'USDNAD': 18.36025,
#    'USDNGN': 825.076097,
#    'USDNIO': 36.780022,
#    'USDNOK': 10.27327,
#    'USDNPR': 133.151259,
#    'USDNZD': 1.58883,
#    'USDOMR': 0.384947,
#    'USDPAB': 0.999745,
#    'USDPEN': 3.707497,
#    'USDPGK': 3.73025,
#    'USDPHP': 55.494989,
#    'USDPKR': 282.850036,
#    'USDPLN': 3.931455,
#    'USDPYG': 7355.819564,
#    'USDQAR': 3.64075,
#    'USDRON': 4.515698,
#    'USDRSD': 106.412387,
#    'USDRUB': 92.89505,
#    'USDRWF': 643,
#    'USDSAR': 3.751266,
#    'USDSBD': 8.440171,
#    'USDSCR': 13.33515,
#    'USDSDG': 601.000282,
#    'USDSEK': 10.09073,
#    'USDSGD': 1.326701,
#    'USDSHP': 1.26665,
#    'USDSLE': 22.685399,
#    'USDSLL': 19750.00043,
#    'USDSOS': 571.000285,
#    'USDSRD': 37.174499,
#    'USDSTD': 20697.981008,
#    'USDSYP': 13001.996022,
#    'USDSZL': 18.360438,
#    'USDTHB': 34.703499,
#    'USDTJS': 10.897618,
#    'USDTMT': 3.5,
#    'USDTND': 3.082503,
#    'USDTOP': 2.3388,
#    'USDTRY': 29.138803,
#    'USDTTD': 6.794119,
#    'USDTWD': 31.207988,
#    'USDTZS': 2515.000008,
#    'USDUAH': 37.601071,
#    'USDUGX': 3758.638586,
#    'USDUYU': 39.243538,
#    'USDUZS': 12369.99956,
#    'USDVEF': 3563955.947602,
#    'USDVES': 35.742694,
#    'USDVND': 24330,
#    'USDVUV': 118.70305,
#    'USDWST': 2.708647,
#    'USDXAF': 597.280194,
#    'USDXAG': 0.040866,
#    'USDXAU': 0.000487,
#    'USDXCD': 2.70255,
#    'USDXDR': 0.745739,
#    'USDXOF': 597.999789,
#    'USDXPF': 108.85048,
#    'USDYER': 249.79682,
#    'USDZAR': 18.25935,
#    'USDZMK': 9001.173275,
#    'USDZMW': 25.314762,
#    'USDZWL': 321.999592},
#   '2023-12-22': {'USDAED': 3.672345,
#    'USDAFN': 70.036226,
#    'USDALL': 94.194017,
#    'USDAMD': 404.933654,
#    'USDANG': 1.804076,
#    'USDAOA': 831.503981,
#    'USDARS': 803.395148,
#    'USDAUD': 1.470804,
#    'USDAWG': 1.8025,
#    'USDAZN': 1.70397,
#    'USDBAM': 1.775732,
#    'USDBBD': 2.021154,
#    'USDBDT': 109.868759,
#    'USDBGN': 1.775253,
#    'USDBHD': 0.376935,
#    'USDBIF': 2850.54111,
#    'USDBMD': 1,
#    'USDBND': 1.325005,
#    'USDBOB': 6.917465,
#    'USDBRL': 4.859041,
#    'USDBSD': 1.001044,
#    'USDBTC': 2.2715624e-05,
#    'USDBTN': 83.226837,
#    'USDBWP': 13.418675,
#    'USDBYN': 3.297896,
#    'USDBYR': 19600,
#    'USDBZD': 2.017795,
#    'USDCAD': 1.32905,
#    'USDCDF': 2860.000362,
#    'USDCHF': 0.855904,
#    'USDCLF': 0.03234,
#    'USDCLP': 892.370396,
#    'USDCNY': 7.133204,
#    'USDCOP': 3899.03,
#    'USDCRC': 521.503863,
#    'USDCUC': 1,
#    'USDCUP': 26.5,
#    'USDCVE': 100.112128,
#    'USDCZK': 22.326904,
#    'USDDJF': 178.228699,
#    'USDDKK': 6.769204,
#    'USDDOP': 57.603886,
#    'USDDZD': 134.392438,
#    'USDEGP': 30.84652,
#    'USDERN': 15,
#    'USDETB': 56.365609,
#    'USDEUR': 0.90705,
#    'USDFJD': 2.198804,
#    'USDFKP': 0.789361,
#    'USDGBP': 0.78734,
#    'USDGEL': 2.690391,
#    'USDGGP': 0.789361,
#    'USDGHS': 12.012729,
#    'USDGIP': 0.789361,
#    'USDGMD': 67.37504,
#    'USDGNF': 8560.000355,
#    'USDGTQ': 7.828112,
#    'USDGYD': 209.439675,
#    'USDHKD': 7.81695,
#    'USDHNL': 24.693813,
#    'USDHRK': 6.98177,
#    'USDHTG': 132.145192,
#    'USDHUF': 345.880388,
#    'USDIDR': 15466.85,
#    'USDILS': 3.60697,
#    'USDIMP': 0.789361,
#    'USDINR': 83.33525,
#    'USDIQD': 1311.350389,
#    'USDIRR': 42275.000352,
#    'USDISK': 136.670386,
#    'USDJEP': 0.789361,
#    'USDJMD': 155.159108,
#    'USDJOD': 0.709404,
#    'USDJPY': 142.39504,
#    'USDKES': 156.000351,
#    'USDKGS': 89.22504,
#    'USDKHR': 4106.442475,
#    'USDKMF': 447.303796,
#    'USDKPW': 899.995986,
#    'USDKRW': 1299.760384,
#    'USDKWD': 0.30723,
#    'USDKYD': 0.834207,
#    'USDKZT': 459.295173,
#    'USDLAK': 20584.616921,
#    'USDLBP': 15045.212718,
#    'USDLKR': 325.85652,
#    'USDLRD': 188.350382,
#    'USDLSL': 18.360382,
#    'USDLTL': 2.95274,
#    'USDLVL': 0.60489,
#    'USDLYD': 4.80276,
#    'USDMAD': 9.897904,
#    'USDMDL': 17.617526,
#    'USDMGA': 4612.102229,
#    'USDMKD': 55.935612,
#    'USDMMK': 2102.138091,
#    'USDMNT': 3435.322022,
#    'USDMOP': 8.056489,
#    'USDMRU': 39.580379,
#    'USDMUR': 44.010379,
#    'USDMVR': 15.350378,
#    'USDMWK': 1685.051523,
#    'USDMXN': 16.975039,
#    'USDMYR': 4.655504,
#    'USDMZN': 63.24995,
#    'USDNAD': 18.360377,
#    'USDNGN': 903.890377,
#    'USDNIO': 36.633861,
#    'USDNOK': 10.20615,
#    'USDNPR': 133.162649,
#    'USDNZD': 1.588563,
#    'USDOMR': 0.384961,
#    'USDPAB': 1.001076,
#    'USDPEN': 3.697005,
#    'USDPGK': 3.735144,
#    'USDPHP': 55.467504,
#    'USDPKR': 279.285033,
#    'USDPLN': 3.935706,
#    'USDPYG': 7375.73199,
#    'USDQAR': 3.64075,
#    'USDRON': 4.514304,
#    'USDRSD': 106.371392,
#    'USDRUB': 92.125038,
#    'USDRWF': 1257.342594,
#    'USDSAR': 3.75101,
#    'USDSBD': 8.440171,
#    'USDSCR': 13.447759,
#    'USDSDG': 601.00034,
#    'USDSEK': 10.014604,
#    'USDSGD': 1.324604,
#    'USDSHP': 1.26665,
#    'USDSLE': 22.683136,
#    'USDSLL': 19750.000338,
#    'USDSOS': 571.000338,
#    'USDSRD': 36.946038,
#    'USDSTD': 20697.981008,
#    'USDSYP': 13001.640217,
#    'USDSZL': 18.420264,
#    'USDTHB': 34.55037,
#    'USDTJS': 10.946108,
#    'USDTMT': 3.5,
#    'USDTND': 3.082504,
#    'USDTOP': 2.33825,
#    'USDTRY': 29.090368,
#    'USDTTD': 6.810392,
#    'USDTWD': 31.104504,
#    'USDTZS': 2517.590449,
#    'USDUAH': 37.526896,
#    'USDUGX': 3766.972485,
#    'USDUYU': 39.512809,
#    'USDUZS': 12397.350753,
#    'USDVEF': 3568026.021203,
#    'USDVES': 35.742694,
#    'USDVND': 24250,
#    'USDVUV': 118.485792,
#    'USDWST': 2.708677,
#    'USDXAF': 595.539516,
#    'USDXAG': 0.041329,
#    'USDXAU': 0.000487,
#    'USDXCD': 2.70255,
#    'USDXDR': 0.746743,
#    'USDXOF': 595.539516,
#    'USDXPF': 108.850364,
#    'USDYER': 249.803595,
#    'USDZAR': 18.47498,
#    'USDZMK': 9001.203591,
#    'USDZMW': 25.421036,
#    'USDZWL': 321.999592},
#   '2023-12-23': {'USDAED': 3.672504,
#    'USDAFN': 69.938283,
#    'USDALL': 94.345439,
#    'USDAMD': 402.623731,
#    'USDANG': 1.793927,
#    'USDAOA': 846.240166,
#    'USDARS': 803.395148,
#    'USDAUD': 1.470372,
#    'USDAWG': 1.8025,
#    'USDAZN': 1.70397,
#    'USDBAM': 1.773566,
#    'USDBBD': 2.018771,
#    'USDBDT': 109.734754,
#    'USDBGN': 1.775589,
#    'USDBHD': 0.376423,
#    'USDBIF': 2847.15484,
#    'USDBMD': 1,
#    'USDBND': 1.323419,
#    'USDBOB': 6.909091,
#    'USDBRL': 4.859104,
#    'USDBSD': 0.999864,
#    'USDBTC': 2.2858606e-05,
#    'USDBTN': 83.128724,
#    'USDBWP': 13.402856,
#    'USDBYN': 3.294038,
#    'USDBYR': 19600,
#    'USDBZD': 2.015416,
#    'USDCAD': 1.328504,
#    'USDCDF': 2860.000362,
#    'USDCHF': 0.855894,
#    'USDCLF': 0.03234,
#    'USDCLP': 875.157561,
#    'USDCNY': 7.093304,
#    'USDCOP': 3945.227839,
#    'USDCRC': 520.879619,
#    'USDCUC': 1,
#    'USDCUP': 26.5,
#    'USDCVE': 99.990932,
#    'USDCZK': 22.326804,
#    'USDDJF': 178.01859,
#    'USDDKK': 6.76975,
#    'USDDOP': 57.592383,
#    'USDDZD': 134.209023,
#    'USDEGP': 30.84652,
#    'USDERN': 15,
#    'USDETB': 56.299161,
#    'USDEUR': 0.90705,
#    'USDFJD': 2.198804,
#    'USDFKP': 0.786265,
#    'USDGBP': 0.787464,
#    'USDGEL': 2.690391,
#    'USDGGP': 0.786265,
#    'USDGHS': 11.998186,
#    'USDGIP': 0.786265,
#    'USDGMD': 67.37504,
#    'USDGNF': 8594.876445,
#    'USDGTQ': 7.818635,
#    'USDGYD': 209.186126,
#    'USDHKD': 7.816704,
#    'USDHNL': 24.664702,
#    'USDHRK': 6.98177,
#    'USDHTG': 131.988211,
#    'USDHUF': 345.89504,
#    'USDIDR': 15466.85,
#    'USDILS': 3.60697,
#    'USDIMP': 0.786265,
#    'USDINR': 83.172504,
#    'USDIQD': 1309.816368,
#    'USDIRR': 42275.000352,
#    'USDISK': 136.670386,
#    'USDJEP': 0.786265,
#    'USDJMD': 154.976196,
#    'USDJOD': 0.709404,
#    'USDJPY': 142.410385,
#    'USDKES': 154.676944,
#    'USDKGS': 89.22504,
#    'USDKHR': 4101.564271,
#    'USDKMF': 447.250384,
#    'USDKPW': 900.012564,
#    'USDKRW': 1299.030384,
#    'USDKWD': 0.30723,
#    'USDKYD': 0.83319,
#    'USDKZT': 458.734981,
#    'USDLAK': 20559.510315,
#    'USDLBP': 15027.612786,
#    'USDLKR': 325.45908,
#    'USDLRD': 188.350382,
#    'USDLSL': 18.360382,
#    'USDLTL': 2.95274,
#    'USDLVL': 0.60489,
#    'USDLYD': 4.797098,
#    'USDMAD': 9.885922,
#    'USDMDL': 17.596917,
#    'USDMGA': 4606.665155,
#    'USDMKD': 55.873951,
#    'USDMMK': 2099.659941,
#    'USDMNT': 3439.819174,
#    'USDMOP': 8.047064,
#    'USDMRU': 39.580379,
#    'USDMUR': 43.944684,
#    'USDMVR': 15.350378,
#    'USDMWK': 1683.065065,
#    'USDMXN': 16.975039,
#    'USDMYR': 4.655504,
#    'USDMZN': 63.24995,
#    'USDNAD': 18.360377,
#    'USDNGN': 903.890377,
#    'USDNIO': 36.590342,
#    'USDNOK': 10.196104,
#    'USDNPR': 133.005668,
#    'USDNZD': 1.588563,
#    'USDOMR': 0.384439,
#    'USDPAB': 0.999864,
#    'USDPEN': 3.692496,
#    'USDPGK': 3.730673,
#    'USDPHP': 55.335039,
#    'USDPKR': 278.955792,
#    'USDPLN': 3.935534,
#    'USDPYG': 7367.036953,
#    'USDQAR': 3.64075,
#    'USDRON': 4.514038,
#    'USDRSD': 106.265246,
#    'USDRUB': 92.125038,
#    'USDRWF': 1255.860349,
#    'USDSAR': 3.750988,
#    'USDSBD': 8.440171,
#    'USDSCR': 13.95221,
#    'USDSDG': 601.00034,
#    'USDSEK': 10.011104,
#    'USDSGD': 1.325038,
#    'USDSHP': 1.26665,
#    'USDSLE': 22.428156,
#    'USDSLL': 19750.000338,
#    'USDSOS': 571.000338,
#    'USDSRD': 36.946038,
#    'USDSTD': 20697.981008,
#    'USDSYP': 13001.960793,
#    'USDSZL': 18.398549,
#    'USDTHB': 34.605038,
#    'USDTJS': 10.933303,
#    'USDTMT': 3.5,
#    'USDTND': 3.082504,
#    'USDTOP': 2.33825,
#    'USDTRY': 29.090368,
#    'USDTTD': 6.802086,
#    'USDTWD': 31.104504,
#    'USDTZS': 2514.622535,
#    'USDUAH': 37.482657,
#    'USDUGX': 3762.412151,
#    'USDUYU': 39.464974,
#    'USDUZS': 12382.679664,
#    'USDVEF': 3574269.440024,
#    'USDVES': 35.742694,
#    'USDVND': 24250,
#    'USDVUV': 117.769036,
#    'USDWST': 2.706792,
#    'USDXAF': 594.837452,
#    'USDXAG': 0.041329,
#    'USDXAU': 0.000487,
#    'USDXCD': 2.70255,
#    'USDXDR': 0.745863,
#    'USDXOF': 594.837452,
#    'USDXPF': 108.850364,
#    'USDYER': 249.803595,
#    'USDZAR': 18.484904,
#    'USDZMK': 9001.203591,
#    'USDZMW': 25.391068,
#    'USDZWL': 321.999592},
#   '2023-12-24': {'USDAED': 3.672503,
#    'USDAFN': 69.968346,
#    'USDALL': 93.998199,
#    'USDAMD': 402.592075,
#    'USDANG': 1.787303,
#    'USDAOA': 831.499468,
#    'USDARS': 805.282615,
#    'USDAUD': 1.471425,
#    'USDAWG': 1.8025,
#    'USDAZN': 1.700271,
#    'USDBAM': 1.775788,
#    'USDBBD': 2.021301,
#    'USDBDT': 109.87225,
#    'USDBGN': 1.775698,
#    'USDBHD': 0.377439,
#    'USDBIF': 2850.722282,
#    'USDBMD': 1,
#    'USDBND': 1.325077,
#    'USDBOB': 6.917748,
#    'USDBRL': 4.892543,
#    'USDBSD': 1.001117,
#    'USDBTC': 2.3243019e-05,
#    'USDBTN': 83.232883,
#    'USDBWP': 13.41965,
#    'USDBYN': 3.298165,
#    'USDBYR': 19600,
#    'USDBZD': 2.017941,
#    'USDCAD': 1.32725,
#    'USDCDF': 2859.999854,
#    'USDCHF': 0.855985,
#    'USDCLF': 0.031756,
#    'USDCLP': 876.25412,
#    'USDCNY': 7.093296,
#    'USDCOP': 3950.17115,
#    'USDCRC': 521.532273,
#    'USDCUC': 1,
#    'USDCUP': 26.5,
#    'USDCVE': 100.116219,
#    'USDCZK': 22.32545,
#    'USDDJF': 178.241644,
#    'USDDKK': 6.769115,
#    'USDDOP': 57.664545,
#    'USDDZD': 134.377185,
#    'USDEGP': 30.881525,
#    'USDERN': 15,
#    'USDETB': 56.369703,
#    'USDEUR': 0.90705,
#    'USDFJD': 2.198796,
#    'USDFKP': 0.787302,
#    'USDGBP': 0.788924,
#    'USDGEL': 2.689936,
#    'USDGGP': 0.787302,
#    'USDGHS': 12.01322,
#    'USDGIP': 0.787302,
#    'USDGMD': 67.375013,
#    'USDGNF': 8605.645696,
#    'USDGTQ': 7.828432,
#    'USDGYD': 209.448233,
#    'USDHKD': 7.81329,
#    'USDHNL': 24.695606,
#    'USDHRK': 6.98177,
#    'USDHTG': 132.153591,
#    'USDHUF': 346.062004,
#    'USDIDR': 15466.85,
#    'USDILS': 3.60465,
#    'USDIMP': 0.787302,
#    'USDINR': 83.172502,
#    'USDIQD': 1311.457548,
#    'USDIRR': 42275.000075,
#    'USDISK': 136.670517,
#    'USDJEP': 0.787302,
#    'USDJMD': 155.170379,
#    'USDJOD': 0.709398,
#    'USDJPY': 142.447503,
#    'USDKES': 154.870752,
#    'USDKGS': 89.224959,
#    'USDKHR': 4106.703469,
#    'USDKMF': 447.250134,
#    'USDKPW': 900,
#    'USDKRW': 1299.359705,
#    'USDKWD': 0.30723,
#    'USDKYD': 0.834234,
#    'USDKZT': 459.309769,
#    'USDLAK': 20585.271071,
#    'USDLBP': 15046.442158,
#    'USDLKR': 325.866875,
#    'USDLRD': 188.349747,
#    'USDLSL': 18.360409,
#    'USDLTL': 2.95274,
#    'USDLVL': 0.60489,
#    'USDLYD': 4.803109,
#    'USDMAD': 9.898308,
#    'USDMDL': 17.618965,
#    'USDMGA': 4612.437237,
#    'USDMKD': 55.943961,
#    'USDMMK': 2102.290783,
#    'USDMNT': 3421.983327,
#    'USDMOP': 8.057147,
#    'USDMRU': 39.580119,
#    'USDMUR': 43.999746,
#    'USDMVR': 15.349745,
#    'USDMWK': 1685.17392,
#    'USDMXN': 17.01184,
#    'USDMYR': 4.655502,
#    'USDMZN': 63.24995,
#    'USDNAD': 18.360218,
#    'USDNGN': 903.890194,
#    'USDNIO': 36.636189,
#    'USDNOK': 10.211815,
#    'USDNPR': 133.172322,
#    'USDNZD': 1.588192,
#    'USDOMR': 0.384921,
#    'USDPAB': 1.001117,
#    'USDPEN': 3.697123,
#    'USDPGK': 3.735348,
#    'USDPHP': 55.334983,
#    'USDPKR': 279.30532,
#    'USDPLN': 3.93482,
#    'USDPYG': 7376.267739,
#    'USDQAR': 3.64075,
#    'USDRON': 4.514017,
#    'USDRSD': 106.398395,
#    'USDRUB': 92.124959,
#    'USDRWF': 1257.433923,
#    'USDSAR': 3.751016,
#    'USDSBD': 8.440171,
#    'USDSCR': 13.969692,
#    'USDSDG': 600.999691,
#    'USDSEK': 10.000798,
#    'USDSGD': 1.323695,
#    'USDSHP': 1.26665,
#    'USDSLE': 22.684998,
#    'USDSLL': 19750.000226,
#    'USDSOS': 570.999862,
#    'USDSRD': 36.945982,
#    'USDSTD': 20697.981008,
#    'USDSYP': 13001.855133,
#    'USDSZL': 18.421602,
#    'USDTHB': 34.608503,
#    'USDTJS': 10.947002,
#    'USDTMT': 3.5,
#    'USDTND': 3.0825,
#    'USDTOP': 2.33825,
#    'USDTRY': 29.142502,
#    'USDTTD': 6.810609,
#    'USDTWD': 31.104497,
#    'USDTZS': 2517.773319,
#    'USDUAH': 37.529622,
#    'USDUGX': 3767.126397,
#    'USDUYU': 39.514423,
#    'USDUZS': 12398.194975,
#    'USDVEF': 3563992.338368,
#    'USDVES': 35.742694,
#    'USDVND': 24250,
#    'USDVUV': 117.231647,
#    'USDWST': 2.683112,
#    'USDXAF': 595.582774,
#    'USDXAG': 0.041329,
#    'USDXAU': 0.000487,
#    'USDXCD': 2.70255,
#    'USDXDR': 0.746797,
#    'USDXOF': 595.582774,
#    'USDXPF': 108.850147,
#    'USDYER': 249.798055,
#    'USDZAR': 18.5037,
#    'USDZMK': 9001.200595,
#    'USDZMW': 25.422882,
#    'USDZWL': 321.999592},
#   '2023-12-25': {'USDAED': 3.672601,
#    'USDAFN': 70.087132,
#    'USDALL': 94.264194,
#    'USDAMD': 405.329895,
#    'USDANG': 1.805421,
#    'USDAOA': 831.510825,
#    'USDARS': 803.923686,
#    'USDAUD': 1.46942,
#    'USDAWG': 1.8025,
#    'USDAZN': 1.653992,
#    'USDBAM': 1.776982,
#    'USDBBD': 2.02266,
#    'USDBDT': 109.946122,
#    'USDBGN': 1.77754,
#    'USDBHD': 0.376116,
#    'USDBIF': 2852.638943,
#    'USDBMD': 1,
#    'USDBND': 1.325968,
#    'USDBOB': 6.922399,
#    'USDBRL': 4.892443,
#    'USDBSD': 1.00179,
#    'USDBTC': 2.292407e-05,
#    'USDBTN': 83.288844,
#    'USDBWP': 13.428673,
#    'USDBYN': 3.300383,
#    'USDBYR': 19600,
#    'USDBZD': 2.019298,
#    'USDCAD': 1.32525,
#    'USDCDF': 2860.000276,
#    'USDCHF': 0.855995,
#    'USDCLF': 0.032354,
#    'USDCLP': 892.740201,
#    'USDCNY': 7.136501,
#    'USDCOP': 3952.83,
#    'USDCRC': 521.882922,
#    'USDCUC': 1,
#    'USDCUP': 26.5,
#    'USDCVE': 100.183531,
#    'USDCZK': 22.269097,
#    'USDDJF': 177.719927,
#    'USDDKK': 6.7656,
#    'USDDOP': 57.703315,
#    'USDDZD': 134.099579,
#    'USDEGP': 30.867374,
#    'USDERN': 15,
#    'USDETB': 56.407603,
#    'USDEUR': 0.90748,
#    'USDFJD': 2.198804,
#    'USDFKP': 0.787909,
#    'USDGBP': 0.78715,
#    'USDGEL': 2.689967,
#    'USDGGP': 0.787909,
#    'USDGHS': 12.021297,
#    'USDGIP': 0.787909,
#    'USDGMD': 67.37502,
#    'USDGNF': 8611.431635,
#    'USDGTQ': 7.833695,
#    'USDGYD': 209.589054,
#    'USDHKD': 7.80995,
#    'USDHNL': 24.71221,
#    'USDHRK': 6.98177,
#    'USDHTG': 132.242443,
#    'USDHUF': 346.369577,
#    'USDIDR': 15467,
#    'USDILS': 3.61312,
#    'USDIMP': 0.787909,
#    'USDINR': 83.17255,
#    'USDIQD': 1312.339297,
#    'USDIRR': 42275.000277,
#    'USDISK': 136.569621,
#    'USDJEP': 0.787909,
#    'USDJMD': 155.274706,
#    'USDJOD': 0.709399,
#    'USDJPY': 142.234984,
#    'USDKES': 154.970222,
#    'USDKGS': 89.164298,
#    'USDKHR': 4109.389906,
#    'USDKMF': 447.250023,
#    'USDKPW': 900.000252,
#    'USDKRW': 1295.580153,
#    'USDKWD': 0.30723,
#    'USDKYD': 0.834795,
#    'USDKZT': 459.618582,
#    'USDLAK': 20599.111418,
#    'USDLBP': 15056.558516,
#    'USDLKR': 326.085969,
#    'USDLRD': 188.350222,
#    'USDLSL': 18.359952,
#    'USDLTL': 2.95274,
#    'USDLVL': 0.60489,
#    'USDLYD': 4.806338,
#    'USDMAD': 9.904964,
#    'USDMDL': 17.630811,
#    'USDMGA': 4615.538373,
#    'USDMKD': 55.828388,
#    'USDMMK': 2103.704242,
#    'USDMNT': 3415.807111,
#    'USDMOP': 8.062564,
#    'USDMRU': 39.580004,
#    'USDMUR': 43.909374,
#    'USDMVR': 15.350431,
#    'USDMWK': 1686.306933,
#    'USDMXN': 16.9902,
#    'USDMYR': 4.63199,
#    'USDMZN': 63.24995,
#    'USDNAD': 18.359742,
#    'USDNGN': 904.570077,
#    'USDNIO': 36.660822,
#    'USDNOK': 10.2012,
#    'USDNPR': 133.261859,
#    'USDNZD': 1.586546,
#    'USDOMR': 0.384125,
#    'USDPAB': 1.00179,
#    'USDPEN': 3.699608,
#    'USDPGK': 3.737859,
#    'USDPHP': 55.393911,
#    'USDPKR': 279.493108,
#    'USDPLN': 3.9382,
#    'USDPYG': 7381.227115,
#    'USDQAR': 3.64075,
#    'USDRON': 4.510995,
#    'USDRSD': 106.469931,
#    'USDRUB': 91.992495,
#    'USDRWF': 1258.279349,
#    'USDSAR': 3.750988,
#    'USDSBD': 8.440171,
#    'USDSCR': 13.979085,
#    'USDSDG': 601.000206,
#    'USDSEK': 9.99445,
#    'USDSGD': 1.325099,
#    'USDSHP': 1.26665,
#    'USDSLE': 22.831315,
#    'USDSLL': 19749.999886,
#    'USDSOS': 571.000101,
#    'USDSRD': 36.946014,
#    'USDSTD': 20697.981008,
#    'USDSYP': 13001.862731,
#    'USDSZL': 18.433988,
#    'USDTHB': 34.573969,
#    'USDTJS': 10.954363,
#    'USDTMT': 3.5,
#    'USDTND': 3.082496,
#    'USDTOP': 2.33825,
#    'USDTRY': 29.316403,
#    'USDTTD': 6.815188,
#    'USDTWD': 31.134698,
#    'USDTZS': 2519.466013,
#    'USDUAH': 37.554855,
#    'USDUGX': 3769.659195,
#    'USDUYU': 39.54099,
#    'USDUZS': 12406.530805,
#    'USDVEF': 3569726.415519,
#    'USDVES': 35.742694,
#    'USDVND': 24245,
#    'USDVUV': 117.01487,
#    'USDWST': 2.683111,
#    'USDXAF': 595.98321,
#    'USDXAG': 0.041329,
#    'USDXAU': 0.000487,
#    'USDXCD': 2.70255,
#    'USDXDR': 0.747299,
#    'USDXOF': 595.98321,
#    'USDXPF': 108.850391,
#    'USDYER': 249.800062,
#    'USDZAR': 18.492601,
#    'USDZMK': 9001.196707,
#    'USDZMW': 25.439975,
#    'USDZWL': 321.999592},
#   '2023-12-26': {'USDAED': 3.67265,
#    'USDAFN': 69.999719,
#    'USDALL': 94.13155,
#    'USDAMD': 405.200912,
#    'USDANG': 1.805421,
#    'USDAOA': 831.999711,
#    'USDARS': 802.231177,
#    'USDAUD': 1.465524,
#    'USDAWG': 1.8,
#    'USDAZN': 1.702956,
#    'USDBAM': 1.776982,
#    'USDBBD': 2.02266,
#    'USDBDT': 109.946122,
#    'USDBGN': 1.7724,
#    'USDBHD': 0.37707,
#    'USDBIF': 2856,
#    'USDBMD': 1,
#    'USDBND': 1.325968,
#    'USDBOB': 6.922399,
#    'USDBRL': 4.814981,
#    'USDBSD': 1.00179,
#    'USDBTC': 2.3519475e-05,
#    'USDBTN': 83.288844,
#    'USDBWP': 13.428673,
#    'USDBYN': 3.300383,
#    'USDBYR': 19600,
#    'USDBZD': 2.019298,
#    'USDCAD': 1.31968,
#    'USDCDF': 2675.000072,
#    'USDCHF': 0.853785,
#    'USDCLF': 0.032353,
#    'USDCLP': 892.709887,
#    'USDCNY': 7.143398,
#    'USDCOP': 3859.75,
#    'USDCRC': 521.882922,
#    'USDCUC': 1,
#    'USDCUP': 26.5,
#    'USDCVE': 100.350121,
#    'USDCZK': 22.2196,
#    'USDDJF': 177.719789,
#    'USDDKK': 6.751265,
#    'USDDOP': 57.650101,
#    'USDDZD': 134.150067,
#    'USDEGP': 30.806098,
#    'USDERN': 15,
#    'USDETB': 56.150364,
#    'USDEUR': 0.905595,
#    'USDFJD': 2.2115,
#    'USDFKP': 0.787673,
#    'USDGBP': 0.78577,
#    'USDGEL': 2.68958,
#    'USDGGP': 0.787673,
#    'USDGHS': 12.030259,
#    'USDGIP': 0.787673,
#    'USDGMD': 67.401748,
#    'USDGNF': 8559.999708,
#    'USDGTQ': 7.833695,
#    'USDGYD': 209.589054,
#    'USDHKD': 7.80754,
#    'USDHNL': 24.750231,
#    'USDHRK': 6.98177,
#    'USDHTG': 132.242443,
#    'USDHUF': 345.77033,
#    'USDIDR': 15407,
#    'USDILS': 3.62912,
#    'USDIMP': 0.787673,
#    'USDINR': 83.18305,
#    'USDIQD': 1310,
#    'USDIRR': 42012.49611,
#    'USDISK': 136.349886,
#    'USDJEP': 0.787673,
#    'USDJMD': 155.274706,
#    'USDJOD': 0.709404,
#    'USDJPY': 142.464495,
#    'USDKES': 156.000413,
#    'USDKGS': 89.006597,
#    'USDKHR': 4107.497242,
#    'USDKMF': 446.149859,
#    'USDKPW': 899.999984,
#    'USDKRW': 1294.920045,
#    'USDKWD': 0.30745,
#    'USDKYD': 0.834795,
#    'USDKZT': 459.618582,
#    'USDLAK': 20589.999907,
#    'USDLBP': 15064.999996,
#    'USDLKR': 326.085969,
#    'USDLRD': 188.34976,
#    'USDLSL': 18.630033,
#    'USDLTL': 2.95274,
#    'USDLVL': 0.60489,
#    'USDLYD': 4.785047,
#    'USDMAD': 9.913497,
#    'USDMDL': 17.630811,
#    'USDMGA': 4584.999823,
#    'USDMKD': 55.91959,
#    'USDMMK': 2103.704242,
#    'USDMNT': 3443.344665,
#    'USDMOP': 8.062564,
#    'USDMRU': 39.549956,
#    'USDMUR': 43.979716,
#    'USDMVR': 15.398067,
#    'USDMWK': 1682.000359,
#    'USDMXN': 16.988598,
#    'USDMYR': 4.638497,
#    'USDMZN': 63.24995,
#    'USDNAD': 18.630045,
#    'USDNGN': 905.093742,
#    'USDNIO': 36.703764,
#    'USDNOK': 10.14684,
#    'USDNPR': 133.261859,
#    'USDNZD': 1.58031,
#    'USDOMR': 0.384753,
#    'USDPAB': 1.00179,
#    'USDPEN': 3.690254,
#    'USDPGK': 3.72765,
#    'USDPHP': 55.35198,
#    'USDPKR': 282.502436,
#    'USDPLN': 3.918722,
#    'USDPYG': 7381.227115,
#    'USDQAR': 3.641005,
#    'USDRON': 4.5006,
#    'USDRSD': 106.469931,
#    'USDRUB': 91.630092,
#    'USDRWF': 1262.5,
#    'USDSAR': 3.75075,
#    'USDSBD': 8.439834,
#    'USDSCR': 14.12993,
#    'USDSDG': 1.32375,
#    'USDSEK': 9.996381,
#    'USDSGD': 1.323405,
#    'USDSHP': 1.27225,
#    'USDSLE': 22.845086,
#    'USDSLL': 19750.000295,
#    'USDSOS': 571.000248,
#    'USDSRD': 36.946036,
#    'USDSTD': 20697.981008,
#    'USDSYP': 13001.957728,
#    'USDSZL': 18.630147,
#    'USDTHB': 34.557504,
#    'USDTJS': 10.954363,
#    'USDTMT': 3.51,
#    'USDTND': 3.077501,
#    'USDTOP': 2.33825,
#    'USDTRY': 29.310899,
#    'USDTTD': 6.815188,
#    'USDTWD': 30.958018,
#    'USDTZS': 2519.466006,
#    'USDUAH': 37.554855,
#    'USDUGX': 3769.659195,
#    'USDUYU': 39.54099,
#    'USDUZS': 12365.000295,
#    'USDVEF': 3576888.723179,
#    'USDVES': 35.737999,
#    'USDVND': 24335,
#    'USDVUV': 117.762374,
#    'USDWST': 2.708546,
#    'USDXAF': 595.98321,
#    'USDXAG': 0.041328,
#    'USDXAU': 0.000484,
#    'USDXCD': 2.70255,
#    'USDXDR': 0.747299,
#    'USDXOF': 595.501076,
#    'USDXPF': 108.450209,
#    'USDYER': 250.324982,
#    'USDZAR': 18.746915,
# ...
#    'USDAOA': 832.505018,
#    'USDARS': 852.249986,
#    'USDAUD': 1.525169,
#    'USDAWG': 1.8,
#    'USDAZN': 1.695038,
#    'USDBAM': 1.798619,
#    'USDBBD': 2.024389,
#    'USDBDT': 110.043315,
#    'USDBGN': 1.798799,
#    'USDBHD': 0.376881,
#    'USDBIF': 2868.060218,
#    'USDBMD': 1,
#    'USDBND': 1.340917,
#    'USDBOB': 6.929568,
#    'USDBRL': 5.030595,
#    'USDBSD': 1.002584,
#    'USDBTC': 1.4792077e-05,
#    'USDBTN': 83.124362,
#    'USDBWP': 13.687821,
#    'USDBYN': 3.281251,
#    'USDBYR': 19600,
#    'USDBZD': 2.020986,
#    'USDCAD': 1.353575,
#    'USDCDF': 2773.000099,
#    'USDCHF': 0.88756,
#    'USDCLF': 0.034317,
#    'USDCLP': 946.909697,
#    'USDCNY': 7.198103,
#    'USDCNH': 7.207965,
#    'USDCOP': 3889.63,
#    'USDCRC': 510.120564,
#    'USDCUC': 1,
#    'USDCUP': 26.5,
#    'USDCVE': 101.41875,
#    'USDCZK': 23.202649,
#    'USDDJF': 178.546796,
#    'USDDKK': 6.858025,
#    'USDDOP': 59.307148,
#    'USDDZD': 134.392034,
#    'USDEGP': 47.10946,
#    'USDERN': 15,
#    'USDETB': 56.938541,
#    'USDEUR': 0.91967,
#    'USDFJD': 2.26815,
#    'USDFKP': 0.784893,
#    'USDGBP': 0.785755,
#    'USDGEL': 2.679973,
#    'USDGGP': 0.784893,
#    'USDGHS': 13.00033,
#    'USDGIP': 0.784893,
#    'USDGMD': 67.924991,
#    'USDGNF': 8617.883188,
#    'USDGTQ': 7.829106,
#    'USDGYD': 209.800179,
#    'USDHKD': 7.819298,
#    'USDHNL': 24.825034,
#    'USDHRK': 6.882375,
#    'USDHTG': 132.932986,
#    'USDHUF': 363.198478,
#    'USDIDR': 15755,
#    'USDILS': 3.652155,
#    'USDIMP': 0.784893,
#    'USDINR': 82.90685,
#    'USDIQD': 1310,
#    'USDIRR': 42035.000471,
#    'USDISK': 136.939655,
#    'USDJEP': 0.784893,
#    'USDJMD': 154.56276,
#    'USDJOD': 0.708899,
#    'USDJPY': 149.150202,
#    'USDKES': 135.860165,
#    'USDKGS': 89.509753,
#    'USDKHR': 4063.859333,
#    'USDKMF': 452.950368,
#    'USDKPW': 900.000123,
#    'USDKRW': 1338.379832,
#    'USDKWD': 0.30733,
#    'USDKYD': 0.835579,
#    'USDKZT': 451.282429,
#    'USDLAK': 20968.557739,
#    'USDLBP': 89785.541526,
#    'USDLKR': 305.46538,
#    'USDLRD': 192.650343,
#    'USDLSL': 18.950229,
#    'USDLTL': 2.95274,
#    'USDLVL': 0.60489,
#    'USDLYD': 4.832673,
#    'USDMAD': 10.051501,
#    'USDMDL': 17.731449,
#    'USDMGA': 4497.006594,
#    'USDMKD': 56.580085,
#    'USDMMK': 2105.500326,
#    'USDMNT': 3378.606125,
#    'USDMOP': 8.075851,
#    'USDMRU': 39.91501,
#    'USDMUR': 45.969915,
#    'USDMVR': 15.404977,
#    'USDMWK': 1687.802904,
#    'USDMXN': 16.835651,
#    'USDMYR': 4.718497,
#    'USDMZN': 63.49674,
#    'USDNAD': 18.969759,
#    'USDNGN': 1564.460094,
#    'USDNIO': 36.904882,
#    'USDNOK': 10.64842,
#    'USDNPR': 132.9992,
#    'USDNZD': 1.64418,
#    'USDOMR': 0.384938,
#    'USDPAB': 1.002736,
#    'USDPEN': 3.698497,
#    'USDPGK': 3.76725,
#    'USDPHP': 55.671502,
#    'USDPKR': 278.646549,
#    'USDPLN': 3.97605,
#    'USDPYG': 7312.003973,
#    'USDQAR': 3.64075,
#    'USDRON': 4.572991,
#    'USDRSD': 107.794674,
#    'USDRUB': 91.449467,
#    'USDRWF': 1289.96956,
#    'USDSAR': 3.750092,
#    'USDSBD': 8.475185,
#    'USDSCR': 13.506001,
#    'USDSDG': 585.999866,
#    'USDSEK': 10.431935,
#    'USDSGD': 1.33928,
#    'USDSHP': 1.273015,
#    'USDSLE': 22.490053,
#    'USDSLL': 22490.053054,
#    'USDSOS': 571.497124,
#    'USDSRD': 35.194496,
#    'USDSTD': 20697.981008,
#    'USDSVC': 8.773301,
#    'USDSYP': 13001.861114,
#    'USDSZL': 18.903981,
#    'USDTHB': 35.979782,
#    'USDTJS': 10.98879,
#    'USDTMT': 3.51,
#    'USDTND': 3.10275,
#    'USDTOP': 2.3679,
#    'USDTRY': 32.341495,
#    'USDTTD': 6.799768,
#    'USDTWD': 31.643602,
#    'USDTZS': 2551.999889,
#    'USDUAH': 39.097748,
#    'USDUGX': 3896.157649,
#    'USDUYU': 38.520086,
#    'USDUZS': 12592.538096,
#    'USDVEF': 3622263.433922,
#    'USDVES': 36.219996,
#    'USDVND': 24725,
#    'USDVUV': 119.048786,
#    'USDWST': 2.682402,
#    'USDXAF': 603.239868,
#    'USDXAG': 0.039891,
#    'USDXAU': 0.000463,
#    'USDXCD': 2.70255,
#    'USDXDR': 0.752996,
#    'USDXOF': 603.239868,
#    'USDXPF': 110.150211,
#    'USDYER': 250.350302,
#    'USDZAR': 18.959897,
#    'USDZMK': 9001.201294,
#    'USDZMW': 25.611786,
#    'USDZWL': 321.999592},
#   '2024-03-19': {'USDAED': 3.672502,
#    'USDAFN': 72.50029,
#    'USDALL': 94.908796,
#    'USDAMD': 402.331958,
#    'USDANG': 1.802429,
#    'USDAOA': 832.489986,
#    'USDARS': 853.257848,
#    'USDAUD': 1.532309,
#    'USDAWG': 1.8025,
#    'USDAZN': 1.700824,
#    'USDBAM': 1.802655,
#    'USDBBD': 2.019254,
#    'USDBDT': 109.75621,
#    'USDBGN': 1.800115,
#    'USDBHD': 0.376895,
#    'USDBIF': 2868,
#    'USDBMD': 1,
#    'USDBND': 1.342089,
#    'USDBOB': 6.911077,
#    'USDBRL': 5.031502,
#    'USDBSD': 1.000041,
#    'USDBTC': 1.6136017e-05,
#    'USDBTN': 83.028596,
#    'USDBWP': 13.718541,
#    'USDBYN': 3.272317,
#    'USDBYR': 19600,
#    'USDBZD': 2.015844,
#    'USDCAD': 1.357375,
#    'USDCDF': 2784.999611,
#    'USDCHF': 0.888605,
#    'USDCLF': 0.035022,
#    'USDCLP': 966.369752,
#    'USDCNY': 7.198965,
#    'USDCNH': 7.21373,
#    'USDCOP': 3875.68,
#    'USDCRC': 502.799733,
#    'USDCUC': 1,
#    'USDCUP': 26.5,
#    'USDCVE': 101.850428,
#    'USDCZK': 23.271598,
#    'USDDJF': 177.720083,
#    'USDDKK': 6.864987,
#    'USDDOP': 59.100097,
#    'USDDZD': 134.831979,
#    'USDEGP': 47.047993,
#    'USDERN': 15,
#    'USDETB': 56.850162,
#    'USDEUR': 0.920555,
#    'USDFJD': 2.27435,
#    'USDFKP': 0.78544,
#    'USDGBP': 0.786251,
#    'USDGEL': 2.715016,
#    'USDGGP': 0.78544,
#    'USDGHS': 13.000055,
#    'USDGIP': 0.78544,
#    'USDGMD': 67.924973,
#    'USDGNF': 8599.999684,
#    'USDGTQ': 7.800539,
#    'USDGYD': 209.452266,
#    'USDHKD': 7.82275,
#    'USDHNL': 24.825018,
#    'USDHRK': 6.882375,
#    'USDHTG': 132.586144,
#    'USDHUF': 363.404986,
#    'USDIDR': 15725,
#    'USDILS': 3.672506,
#    'USDIMP': 0.78544,
#    'USDINR': 83.04265,
#    'USDIQD': 1310,
#    'USDIRR': 42034.999802,
#    'USDISK': 137.069841,
#    'USDJEP': 0.78544,
#    'USDJMD': 154.093601,
#    'USDJOD': 0.708897,
#    'USDJPY': 151.038972,
#    'USDKES': 134.000175,
#    'USDKGS': 89.51011,
#    'USDKHR': 4054.999809,
#    'USDKMF': 452.949629,
#    'USDKPW': 899.97938,
#    'USDKRW': 1337.414971,
#    'USDKWD': 0.30749,
#    'USDKYD': 0.833399,
#    'USDKZT': 451.753537,
#    'USDLAK': 20940.000109,
#    'USDLBP': 89750.000065,
#    'USDLKR': 303.977142,
#    'USDLRD': 192.64953,
#    'USDLSL': 18.95012,
#    'USDLTL': 2.95274,
#    'USDLVL': 0.60489,
#    'USDLYD': 4.825004,
#    'USDMAD': 10.051504,
#    'USDMDL': 17.726571,
#    'USDMGA': 4508.000072,
#    'USDMKD': 56.703355,
#    'USDMMK': 2100.17927,
#    'USDMNT': 3400.292164,
#    'USDMOP': 8.058437,
#    'USDMRU': 39.915019,
#    'USDMUR': 46.090278,
#    'USDMVR': 15.550187,
#    'USDMWK': 1682.999859,
#    'USDMXN': 16.814896,
#    'USDMYR': 4.733011,
#    'USDMZN': 63.502171,
#    'USDNAD': 18.970033,
#    'USDNGN': 1477.250126,
#    'USDNIO': 36.75005,
#    'USDNOK': 10.644305,
#    'USDNPR': 132.846049,
#    'USDNZD': 1.65332,
#    'USDOMR': 0.384948,
#    'USDPAB': 1.000041,
#    'USDPEN': 3.698978,
#    'USDPGK': 3.76725,
#    'USDPHP': 55.939879,
#    'USDPKR': 278.704623,
#    'USDPLN': 3.97275,
#    'USDPYG': 7303.730673,
#    'USDQAR': 3.64075,
#    'USDRON': 4.578398,
#    'USDRSD': 107.891322,
#    'USDRUB': 91.449882,
#    'USDRWF': 1289,
#    'USDSAR': 3.750148,
#    'USDSBD': 8.475185,
#    'USDSCR': 13.332992,
#    'USDSDG': 586.000107,
#    'USDSEK': 10.43485,
#    'USDSGD': 1.342485,
#    'USDSHP': 1.272974,
#    'USDSLE': 22.592355,
#    'USDSLL': 22592.354936,
#    'USDSOS': 571.501732,
#    'USDSRD': 35.238503,
#    'USDSTD': 20697.981008,
#    'USDSVC': 8.750593,
#    'USDSYP': 13001.807992,
#    'USDSZL': 18.970448,
#    'USDTHB': 36.089501,
#    'USDTJS': 10.970989,
#    'USDTMT': 3.51,
#    'USDTND': 3.10275,
#    'USDTOP': 2.368991,
#    'USDTRY': 32.40607,
#    'USDTTD': 6.788488,
#    'USDTWD': 31.745402,
#    'USDTZS': 2551.99976,
#    'USDUAH': 39.157384,
#    'USDUGX': 3880.345268,
#    'USDUYU': 38.471642,
#    'USDUZS': 12572.496482,
#    'USDVEF': 3624928.073833,
#    'USDVES': 36.219996,
#    'USDVND': 24750,
#    'USDVUV': 119.91961,
#    'USDWST': 2.751039,
#    'USDXAF': 604.593739,
#    'USDXAG': 0.040195,
#    'USDXAU': 0.000464,
#    'USDXCD': 2.70255,
#    'USDXDR': 0.751002,
#    'USDXOF': 601.99989,
#    'USDXPF': 110.149838,
#    'USDYER': 250.349836,
#    'USDZAR': 18.923902,
#    'USDZMK': 9001.197294,
#    'USDZMW': 25.727124,
#    'USDZWL': 321.999592},
#   '2024-03-20': {'USDAED': 3.672496,
#    'USDAFN': 71.274994,
#    'USDALL': 95.103635,
#    'USDAMD': 401.328229,
#    'USDANG': 1.802426,
#    'USDAOA': 835.471583,
#    'USDARS': 853.242205,
#    'USDAUD': 1.515737,
#    'USDAWG': 1.8,
#    'USDAZN': 1.704465,
#    'USDBAM': 1.803927,
#    'USDBBD': 2.019286,
#    'USDBDT': 109.758853,
#    'USDBGN': 1.790198,
#    'USDBHD': 0.376891,
#    'USDBIF': 2870,
#    'USDBMD': 1,
#    'USDBND': 1.344408,
#    'USDBOB': 6.910483,
#    'USDBRL': 4.9677,
#    'USDBSD': 1.000138,
#    'USDBTC': 1.4699555e-05,
#    'USDBTN': 83.138403,
#    'USDBWP': 13.700134,
#    'USDBYN': 3.272843,
#    'USDBYR': 19600,
#    'USDBZD': 2.015957,
#    'USDCAD': 1.34725,
#    'USDCDF': 2785.999987,
#    'USDCHF': 0.885665,
#    'USDCLF': 0.0349,
#    'USDCLP': 963.009761,
#    'USDCNY': 7.1986,
#    'USDCNH': 7.207898,
#    'USDCOP': 3880.61,
#    'USDCRC': 503.251395,
#    'USDCUC': 1,
#    'USDCUP': 26.5,
#    'USDCVE': 102.050402,
#    'USDCZK': 23.053797,
#    'USDDJF': 177.719943,
#    'USDDKK': 6.818502,
#    'USDDOP': 59.202571,
#    'USDDZD': 134.115976,
#    'USDEGP': 46.899196,
#    'USDERN': 15,
#    'USDETB': 56.875004,
#    'USDEUR': 0.914335,
#    'USDFJD': 2.26715,
#    'USDFKP': 0.786688,
#    'USDGBP': 0.78138,
#    'USDGEL': 2.709483,
#    'USDGGP': 0.786688,
#    'USDGHS': 13.014968,
#    'USDGIP': 0.786688,
#    'USDGMD': 67.924987,
#    'USDGNF': 8600.000269,
#    'USDGTQ': 7.800581,
#    'USDGYD': 209.405395,
#    'USDHKD': 7.82305,
#    'USDHNL': 24.780047,
#    'USDHRK': 6.882375,
#    'USDHTG': 132.58685,
#    'USDHUF': 360.185012,
#    'USDIDR': 15694,
#    'USDILS': 3.65533,
#    'USDIMP': 0.786688,
#    'USDINR': 83.05485,
#    'USDIQD': 1310,
#    'USDIRR': 42042.503137,
#    'USDISK': 135.7798,
#    'USDJEP': 0.786688,
#    'USDJMD': 154.065397,
#    'USDJOD': 0.708901,
#    'USDJPY': 150.766499,
#    'USDKES': 133.000218,
#    'USDKGS': 89.509871,
#    'USDKHR': 4050.000324,
#    'USDKMF': 453.750024,
#    'USDKPW': 899.963672,
#    'USDKRW': 1330.564981,
#    'USDKWD': 0.30738,
#    'USDKYD': 0.833464,
#    'USDKZT': 450.675645,
#    'USDLAK': 20949.999865,
#    'USDLBP': 89700.000281,
#    'USDLKR': 304.179599,
#    'USDLRD': 192.625033,
#    'USDLSL': 18.810244,
#    'USDLTL': 2.95274,
#    'USDLVL': 0.60489,
#    'USDLYD': 4.820227,
#    'USDMAD': 10.042501,
#    'USDMDL': 17.752156,
#    'USDMGA': 4482.502983,
#    'USDMKD': 56.245628,
#    'USDMMK': 2100.262879,
#    'USDMNT': 3395.887677,
#    'USDMOP': 8.059309,
#    'USDMRU': 39.879832,
#    'USDMUR': 46.097663,
#    'USDMVR': 15.46499,
#    'USDMWK': 1682.999971,
#    'USDMXN': 16.682705,
#    'USDMYR': 4.74104,
#    'USDMZN': 63.502308,
#    'USDNAD': 18.809579,
#    'USDNGN': 1480.999955,
#    'USDNIO': 36.749885,
#    'USDNOK': 10.55219,
#    'USDNPR': 133.021261,
#    'USDNZD': 1.642291,
#    'USDOMR': 0.384955,
#    'USDPAB': 1.000138,
#    'USDPEN': 3.706031,
#    'USDPGK': 3.769504,
#    'USDPHP': 56.055984,
#    'USDPKR': 278.501322,
#    'USDPLN': 3.942699,
#    'USDPYG': 7304.339805,
#    'USDQAR': 3.641009,
#    'USDRON': 4.545899,
#    'USDRSD': 107.170712,
#    'USDRUB': 92.398083,
#    'USDRWF': 1289,
#    'USDSAR': 3.750366,
#    'USDSBD': 8.454632,
#    'USDSCR': 13.465848,
#    'USDSDG': 586.000239,
#    'USDSEK': 10.369835,
#    'USDSGD': 1.339065,
#    'USDSHP': 1.271976,
#    'USDSLE': 22.598561,
#    'USDSLL': 22598.561186,
#    'USDSOS': 571.495339,
#    'USDSRD': 35.126015,
#    'USDSTD': 20697.981008,
#    'USDSVC': 8.750271,
#    'USDSYP': 13001.839312,
#    'USDSZL': 18.810089,
#    'USDTHB': 35.932498,
#    'USDTJS': 10.961306,
#    'USDTMT': 3.505,
#    'USDTND': 3.091042,
#    'USDTOP': 2.37295,
#    'USDTRY': 32.422502,
#    'USDTTD': 6.788728,
#    'USDTWD': 31.777201,
#    'USDTZS': 2552.000384,
#    'USDUAH': 39.149564,
#    'USDUGX': 3875.704443,
#    'USDUYU': 38.406552,
#    'USDUZS': 12575.000263,
#    'USDVEF': 3621590.065534,
#    'USDVES': 36.21912,
#    'USDVND': 24790,
#    'USDVUV': 120.615214,
#    'USDWST': 2.75222,
#    'USDXAF': 605.04266,
#    'USDXAG': 0.038911,
#    'USDXAU': 0.000454,
#    'USDXCD': 2.70255,
#    'USDXDR': 0.751064,
#    'USDXOF': 603.494587,
#    'USDXPF': 110.349617,
#    'USDYER': 250.324971,
#    'USDZAR': 18.687304,
#    'USDZMK': 9001.203123,
#    'USDZMW': 25.853434,
#    'USDZWL': 321.999592},
#   '2024-03-21': {'USDAED': 3.672497,
#    'USDAFN': 71.199102,
#    'USDALL': 94.056729,
#    'USDAMD': 399.719527,
#    'USDANG': 1.8022,
#    'USDAOA': 832.633035,
#    'USDARS': 854.25002,
#    'USDAUD': 1.521602,
#    'USDAWG': 1.8,
#    'USDAZN': 1.699549,
#    'USDBAM': 1.792643,
#    'USDBBD': 2.018946,
#    'USDBDT': 109.741846,
#    'USDBGN': 1.800598,
#    'USDBHD': 0.376929,
#    'USDBIF': 2860.376667,
#    'USDBMD': 1,
#    'USDBND': 1.339658,
#    'USDBOB': 6.909163,
#    'USDBRL': 4.97597,
#    'USDBSD': 0.999986,
#    'USDBTC': 1.525774e-05,
#    'USDBTN': 83.141387,
#    'USDBWP': 13.632135,
#    'USDBYN': 3.272366,
#    'USDBYR': 19600,
#    'USDBZD': 2.015305,
#    'USDCAD': 1.35295,
#    'USDCDF': 2786.000269,
#    'USDCHF': 0.897795,
#    'USDCLF': 0.035122,
#    'USDCLP': 969.130293,
#    'USDCNY': 7.199198,
#    'USDCNH': 7.221795,
#    'USDCOP': 3889.6,
#    'USDCRC': 502.834516,
#    'USDCUC': 1,
#    'USDCUP': 26.5,
#    'USDCVE': 101.066438,
#    'USDCZK': 23.297001,
#    'USDDJF': 178.041516,
#    'USDDKK': 6.866199,
#    'USDDOP': 59.146216,
#    'USDDZD': 134.641197,
#    'USDEGP': 46.651603,
#    'USDERN': 15,
#    'USDETB': 56.798852,
#    'USDEUR': 0.920645,
#    'USDFJD': 2.272303,
#    'USDFKP': 0.786796,
#    'USDGBP': 0.789855,
#    'USDGEL': 2.710024,
#    'USDGGP': 0.786796,
#    'USDGHS': 13.036484,
#    'USDGIP': 0.786796,
#    'USDGMD': 67.925012,
#    'USDGNF': 8593.832349,
#    'USDGTQ': 7.799267,
#    'USDGYD': 209.364674,
#    'USDHKD': 7.82085,
#    'USDHNL': 24.69077,
#    'USDHRK': 6.882375,
#    'USDHTG': 132.572581,
#    'USDHUF': 363.034989,
#    'USDIDR': 15726.75,
#    'USDILS': 3.60401,
#    'USDIMP': 0.786796,
#    'USDINR': 83.22685,
#    'USDIQD': 1309.86916,
#    'USDIRR': 42042.497378,
#    'USDISK': 136.71008,
#    'USDJEP': 0.786796,
#    'USDJMD': 153.94767,
#    'USDJOD': 0.708905,
#    'USDJPY': 151.637961,
#    'USDKES': 132.505751,
#    'USDKGS': 89.509735,
#    'USDKHR': 4048.486515,
#    'USDKMF': 453.750234,
#    'USDKPW': 900.003682,
#    'USDKRW': 1335.390265,
#    'USDKWD': 0.30744,
#    'USDKYD': 0.833261,
#    'USDKZT': 450.451359,
#    'USDLAK': 20933.717685,
#    'USDLBP': 89547.989716,
#    'USDLKR': 303.950504,
#    'USDLRD': 192.62505,
#    'USDLSL': 18.80935,
#    'USDLTL': 2.95274,
#    'USDLVL': 0.60489,
#    'USDLYD': 4.814849,
#    'USDMAD': 10.040691,
#    'USDMDL': 17.72167,
#    'USDMGA': 4450.901225,
#    'USDMKD': 56.726325,
#    'USDMMK': 2099.87947,
#    'USDMNT': 3394.328559,
#    'USDMOP': 8.055343,
#    'USDMRU': 39.879736,
#    'USDMUR': 46.019751,
#    'USDMVR': 15.465017,
#    'USDMWK': 1733.798344,
#    'USDMXN': 16.741804,
#    'USDMYR': 4.714798,
#    'USDMZN': 63.503112,
#    'USDNAD': 18.809648,
#    'USDNGN': 1370.49024,
#    'USDNIO': 36.800594,
#    'USDNOK': 10.667261,
#    'USDNPR': 133.010127,
#    'USDNZD': 1.65403,
#    'USDOMR': 0.384967,
#    'USDPAB': 0.999771,
#    'USDPEN': 3.695366,
#    'USDPGK': 3.774,
#    'USDPHP': 56.026047,
#    'USDPKR': 278.32397,
#    'USDPLN': 3.96435,
#    'USDPYG': 7314.222864,
#    'USDQAR': 3.641014,
#    'USDRON': 4.578504,
#    'USDRSD': 107.909781,
#    'USDRUB': 92.396955,
#    'USDRWF': 1284.216991,
#    'USDSAR': 3.750257,
#    'USDSBD': 8.454632,
#    'USDSCR': 13.516226,
#    'USDSDG': 585.999975,
#    'USDSEK': 10.466355,
#    'USDSGD': 1.3436,
#    'USDSHP': 1.27203,
#    'USDSLE': 22.61611,
#    'USDSLL': 22616.110192,
#    'USDSOS': 571.433018,
#    'USDSRD': 35.1865,
#    'USDSTD': 20697.981008,
#    'USDSVC': 8.749651,
#    'USDSYP': 13001.854315,
#    'USDSZL': 18.758191,
#    'USDTHB': 36.324981,
#    'USDTJS': 10.95798,
#    'USDTMT': 3.505,
#    'USDTND': 3.091002,
#    'USDTOP': 2.36955,
#    'USDTRY': 32.1615,
#    'USDTTD': 6.787258,
#    'USDTWD': 31.889498,
#    'USDTZS': 2551.999921,
#    'USDUAH': 38.888008,
#    'USDUGX': 3884.456217,
#    'USDUYU': 38.515124,
#    'USDUZS': 12574.702108,
#    'USDVEF': 3621283.044195,
#    'USDVES': 36.21912,
#    'USDVND': 24790,
#    'USDVUV': 120.72038,
#    'USDWST': 2.756642,
#    'USDXAF': 601.230036,
#    'USDXAG': 0.040389,
#    'USDXAU': 0.000458,
#    'USDXCD': 2.70255,
#    'USDXDR': 0.750959,
#    'USDXOF': 601.235547,
#    'USDXPF': 110.350087,
#    'USDYER': 250.325039,
#    'USDZAR': 18.834097,
#    'USDZMK': 9001.197777,
#    'USDZMW': 26.123381,
#    'USDZWL': 321.999592}}}

# %%
specific_date_data
# Out:
# {'success': False,
#  'error': {'code': 104,
#   'info': 'Your monthly usage limit has been reached. Please upgrade your Subscription Plan.'}}
